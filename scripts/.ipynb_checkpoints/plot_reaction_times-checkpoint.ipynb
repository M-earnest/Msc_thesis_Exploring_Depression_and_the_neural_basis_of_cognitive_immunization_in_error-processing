# %% [markdown]
# ToDo
# - clean-up

# %% [markdown]
# - anzahl der Fehler pro Person, pro Bedingung
# - anzahl der corrects pro Person, pro Bedingung
# - standardfehler asu standarabweichung berechnen (wurzel(standardabweichung/aus Anzahl der Fehler))
# - standardafehler auf personen auf personenebene

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import matplotlib.patches as mpatches
import numpy as np
import os
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score #model evaluation

# %%
rootdir = '/home/michael/data/derivatives/results/dataframes'

# %%
rt_df = pd.DataFrame()

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        #print(file)
        #print os.path.join(subdir, file)
        filepath = subdir + os.sep + file
        if filepath.endswith(".tsv"):
            print (filepath)
            if filepath == '/home/michael/data/derivatives/results/dataframes/debugging_rt_data_sub_x.tsv':
                print('no, no')
            else:
                df_temp = pd.read_csv(filepath, sep='\t',  index_col=0) 
                rt_df = rt_df.append(df_temp)
                display(df_temp)
                
rt_df.sort_values(by=('subject'))
# Out:
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-007.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  1.203125  incongruent    left      0
# 1         1          0    correct  0.427734  incongruent   right      0
# 2         2          0    correct  0.420898  incongruent    left      0
# 3         3          0    correct  0.413086    congruent    left      0
# 4         4          0    correct  0.405273  incongruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.505859  incongruent    left      2
# 1244   1244          2    correct  0.482422    congruent   right      2
# 1245   1245          2  incorrect  0.442383  incongruent   right      2
# 1246   1246          2    correct  0.946289  incongruent    left      2
# 1247   1247          2    correct  0.523438    congruent   right      2
#
#       subject  negative_first
# 0           7            True
# 1           7            True
# 2           7            True
# 3           7            True
# 4           7            True
# ...       ...             ...
# 1243        7            True
# 1244        7            True
# 1245        7            True
# 1246        7            True
# 1247        7            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-011.tsv
#       trial  condition reaction        rt       target flanker  block  \
# 0         0          0  correct  0.888672    congruent    left      0
# 1         1          0  correct  1.009766    congruent    left      0
# 2         2          0  correct  0.442383  incongruent   right      0
# 3         3          0  correct  0.451172  incongruent   right      0
# 4         4          0  correct  0.332031    congruent   right      0
# ...     ...        ...      ...       ...          ...     ...    ...
# 1243   1243          3  correct  0.270508    congruent    left      3
# 1244   1244          3  correct  0.263672    congruent    left      3
# 1245   1245          3  correct  0.240234    congruent    left      3
# 1246   1246          3  correct  0.281250    congruent    left      3
# 1247   1247          3  correct  0.272461    congruent    left      3
#
#       subject  negative_first
# 0          11           False
# 1          11           False
# 2          11           False
# 3          11           False
# 4          11           False
# ...       ...             ...
# 1243       11           False
# 1244       11           False
# 1245       11           False
# 1246       11           False
# 1247       11           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-014.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  1.021484  incongruent    left      0
# 1         1          0  incorrect  0.358398    congruent   right      0
# 2         2          0    correct  0.335938    congruent   right      0
# 3         3          0    correct  0.456055  incongruent    left      0
# 4         4          0    correct  0.416992    congruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.386719  incongruent    left      2
# 1244   1244          2    correct  0.363281    congruent   right      2
# 1245   1245          2    correct  0.467773  incongruent    left      2
# 1246   1246          2    correct  0.396484    congruent    left      2
# 1247   1247          2    correct  0.373047    congruent   right      2
#
#       subject  negative_first
# 0          14            True
# 1          14            True
# 2          14            True
# 3          14            True
# 4          14            True
# ...       ...             ...
# 1243       14            True
# 1244       14            True
# 1245       14            True
# 1246       14            True
# 1247       14            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-036.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.692383  incongruent   right      0
# 1         1          0    correct  0.414062    congruent    left      0
# 2         2          0    correct  0.470703  incongruent   right      0
# 3         3          0    correct  0.335938    congruent   right      0
# 4         4          0  incorrect  0.263672  incongruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2  incorrect  0.407227    congruent    left      2
# 1244   1244          2  incorrect  0.462891  incongruent    left      2
# 1245   1245          2    correct  0.616211  incongruent    left      2
# 1246   1246          2    correct  0.480469  incongruent    left      2
# 1247   1247          2    correct  0.537109  incongruent   right      2
#
#       subject  negative_first
# 0          36            True
# 1          36            True
# 2          36            True
# 3          36            True
# 4          36            True
# ...       ...             ...
# 1243       36            True
# 1244       36            True
# 1245       36            True
# 1246       36            True
# 1247       36            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-012.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0        NaN       NaN  incongruent   right      0
# 1         1          0    correct  0.647461  incongruent    left      0
# 2         2          0  incorrect  0.255859  incongruent    left      0
# 3         3          0    correct  0.457031  incongruent   right      0
# 4         4          0  incorrect  0.257812  incongruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.747070    congruent    left      2
# 1244   1244          2    correct  0.499023  incongruent   right      2
# 1245   1245          2    correct  0.444336    congruent   right      2
# 1246   1246          2    correct  0.484375    congruent    left      2
# 1247   1247          2    correct  0.765625  incongruent    left      2
#
#       subject  negative_first
# 0          12            True
# 1          12            True
# 2          12            True
# 3          12            True
# 4          12            True
# ...       ...             ...
# 1243       12            True
# 1244       12            True
# 1245       12            True
# 1246       12            True
# 1247       12            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-035.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.752930    congruent   right      0
# 1         1          0    correct  0.378906  incongruent    left      0
# 2         2          0  incorrect  0.258789  incongruent    left      0
# 3         3          0  incorrect  0.332031  incongruent   right      0
# 4         4          0    correct  0.307617    congruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.362305  incongruent    left      2
# 1244   1244          2    correct  0.354492    congruent    left      2
# 1245   1245          2    correct  0.315430    congruent   right      2
# 1246   1246          2    correct  0.419922  incongruent   right      2
# 1247   1247          2    correct  0.333008    congruent    left      2
#
#       subject  negative_first
# 0          35            True
# 1          35            True
# 2          35            True
# 3          35            True
# 4          35            True
# ...       ...             ...
# 1243       35            True
# 1244       35            True
# 1245       35            True
# 1246       35            True
# 1247       35            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-038.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0  incorrect  0.270508  incongruent    left      0
# 1         1          0  incorrect  0.279297  incongruent    left      0
# 2         2          0    correct  0.416016  incongruent   right      0
# 3         3          0    correct  0.248047    congruent   right      0
# 4         4          0    correct  0.384766    congruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1195   1195          3    correct  0.392578  incongruent    left      3
# 1196   1196          3    correct  0.482422  incongruent    left      3
# 1197   1197          3    correct  0.394531  incongruent   right      3
# 1198   1198          3    correct  0.323242    congruent    left      3
# 1199   1199          3    correct  0.395508  incongruent    left      3
#
#       subject  negative_first
# 0          38           False
# 1          38           False
# 2          38           False
# 3          38           False
# 4          38           False
# ...       ...             ...
# 1195       38           False
# 1196       38           False
# 1197       38           False
# 1198       38           False
# 1199       38           False
#
# [1200 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-010.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.586914    congruent    left      0
# 1         1          0    correct  0.275391    congruent    left      0
# 2         2          0  incorrect  0.204102  incongruent    left      0
# 3         3          0    correct  0.275391    congruent    left      0
# 4         4          0    correct  0.284180    congruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3    correct  0.209961    congruent    left      3
# 1244   1244          3  incorrect  0.234375  incongruent    left      3
# 1245   1245          3    correct  0.226562    congruent   right      3
# 1246   1246          3  incorrect  0.235352  incongruent   right      3
# 1247   1247          3    correct  0.242188    congruent   right      3
#
#       subject  negative_first
# 0          10           False
# 1          10           False
# 2          10           False
# 3          10           False
# 4          10           False
# ...       ...             ...
# 1243       10           False
# 1244       10           False
# 1245       10           False
# 1246       10           False
# 1247       10           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-003.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0        NaN       NaN  incongruent   right      0
# 1         1          0        NaN       NaN  incongruent    left      0
# 2         2          0        NaN       NaN    congruent   right      0
# 3         3          0        NaN       NaN    congruent    left      0
# 4         4          0        NaN       NaN  incongruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.321289    congruent    left      2
# 1244   1244          2    correct  0.457031  incongruent    left      2
# 1245   1245          2    correct  0.337891    congruent    left      2
# 1246   1246          2    correct  0.425781    congruent   right      2
# 1247   1247          2  incorrect  0.370117    congruent    left      2
#
#       subject  negative_first
# 0           3            True
# 1           3            True
# 2           3            True
# 3           3            True
# 4           3            True
# ...       ...             ...
# 1243        3            True
# 1244        3            True
# 1245        3            True
# 1246        3            True
# 1247        3            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-031.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.598633  incongruent   right      0
# 1         1          0    correct  0.287109    congruent    left      0
# 2         2          0  incorrect  0.184570  incongruent    left      0
# 3         3          0  incorrect  0.225586  incongruent    left      0
# 4         4          0    correct  0.776367  incongruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3    correct  0.373047  incongruent   right      3
# 1244   1244          3    correct  0.365234    congruent    left      3
# 1245   1245          3    correct  0.230469    congruent   right      3
# 1246   1246          3    correct  0.253906    congruent   right      3
# 1247   1247          3    correct  0.279297    congruent    left      3
#
#       subject  negative_first
# 0          31           False
# 1          31           False
# 2          31           False
# 3          31           False
# 4          31           False
# ...       ...             ...
# 1243       31           False
# 1244       31           False
# 1245       31           False
# 1246       31           False
# 1247       31           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-005.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.550781    congruent    left      0
# 1         1          0    correct  0.448242  incongruent    left      0
# 2         2          0    correct  0.328125    congruent   right      0
# 3         3          0  incorrect  0.273438  incongruent   right      0
# 4         4          0    correct  0.329102    congruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2  incorrect  0.481445    congruent   right      2
# 1244   1244          2    correct  0.393555    congruent   right      2
# 1245   1245          2    correct  0.483398    congruent    left      2
# 1246   1246          2    correct  0.395508  incongruent   right      2
# 1247   1247          2    correct  0.436523  incongruent    left      2
#
#       subject  negative_first
# 0           5            True
# 1           5            True
# 2           5            True
# 3           5            True
# 4           5            True
# ...       ...             ...
# 1243        5            True
# 1244        5            True
# 1245        5            True
# 1246        5            True
# 1247        5            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-037.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.822266  incongruent   right      0
# 1         1          0    correct  0.479492    congruent    left      0
# 2         2          0    correct  0.424805  incongruent   right      0
# 3         3          0  incorrect  0.336914  incongruent   right      0
# 4         4          0    correct  0.537109    congruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3    correct  0.261719    congruent   right      3
# 1244   1244          3  incorrect  0.318359  incongruent   right      3
# 1245   1245          3    correct  0.407227  incongruent    left      3
# 1246   1246          3    correct  0.334961    congruent   right      3
# 1247   1247          3    correct  0.375977  incongruent   right      3
#
#       subject  negative_first
# 0          37           False
# 1          37           False
# 2          37           False
# 3          37           False
# 4          37           False
# ...       ...             ...
# 1243       37           False
# 1244       37           False
# 1245       37           False
# 1246       37           False
# 1247       37           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-029.tsv
#      trial  condition   reaction        rt       target flanker  block  \
# 0        0          0    correct  0.741211  incongruent    left      0
# 1        1          0    correct  0.254883    congruent    left      0
# 2        2          0  incorrect  0.246094  incongruent   right      0
# 3        3          0    correct  0.286133    congruent   right      0
# 4        4          0    correct  0.230469    congruent    left      0
# ..     ...        ...        ...       ...          ...     ...    ...
# 894    894          3    correct  0.339844  incongruent   right      3
# 895    895          3    correct  0.250977    congruent    left      3
# 896    896          3    correct  0.291992    congruent    left      3
# 897    897          3    correct  0.299805  incongruent   right      3
# 898    898          3    correct  0.259766    congruent    left      3
#
#      subject  negative_first
# 0         29           False
# 1         29           False
# 2         29           False
# 3         29           False
# 4         29           False
# ..       ...             ...
# 894       29           False
# 895       29           False
# 896       29           False
# 897       29           False
# 898       29           False
#
# [899 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-016.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  1.113281    congruent    left      0
# 1         1          0    correct  0.371094    congruent   right      0
# 2         2          0    correct  0.395508  incongruent    left      0
# 3         3          0    correct  0.324219    congruent    left      0
# 4         4          0    correct  0.396484  incongruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.240234    congruent    left      2
# 1244   1244          2  incorrect  0.248047  incongruent    left      2
# 1245   1245          2    correct  0.353516  incongruent   right      2
# 1246   1246          2    correct  0.345703  incongruent    left      2
# 1247   1247          2    correct  0.274414    congruent   right      2
#
#       subject  negative_first
# 0          16            True
# 1          16            True
# 2          16            True
# 3          16            True
# 4          16            True
# ...       ...             ...
# 1243       16            True
# 1244       16            True
# 1245       16            True
# 1246       16            True
# 1247       16            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-033.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.918945  incongruent   right      0
# 1         1          0    correct  0.638672  incongruent   right      0
# 2         2          0    correct  0.296875    congruent   right      0
# 3         3          0  incorrect  0.320312  incongruent   right      0
# 4         4          0    correct  0.297852    congruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3    correct  0.287109    congruent   right      3
# 1244   1244          3    correct  0.456055    congruent    left      3
# 1245   1245          3    correct  0.320312    congruent    left      3
# 1246   1246          3    correct  0.296875    congruent   right      3
# 1247   1247          3    correct  0.432617    congruent   right      3
#
#       subject  negative_first
# 0          33           False
# 1          33           False
# 2          33           False
# 3          33           False
# 4          33           False
# ...       ...             ...
# 1243       33           False
# 1244       33           False
# 1245       33           False
# 1246       33           False
# 1247       33           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-002.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0        NaN       NaN    congruent   right      0
# 1         1          0    correct  0.255859    congruent   right      0
# 2         2          0  incorrect  0.171875  incongruent   right      0
# 3         3          0    correct  0.359375  incongruent    left      0
# 4         4          0    correct  0.354492  incongruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3  incorrect  0.244141  incongruent   right      3
# 1244   1244          3    correct  0.303711    congruent    left      3
# 1245   1245          3    correct  0.347656    congruent    left      3
# 1246   1246          3    correct  0.311523    congruent   right      3
# 1247   1247          3    correct  0.355469    congruent   right      3
#
#       subject  negative_first
# 0           2           False
# 1           2           False
# 2           2           False
# 3           2           False
# 4           2           False
# ...       ...             ...
# 1243        2           False
# 1244        2           False
# 1245        2           False
# 1246        2           False
# 1247        2           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-024.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.495117  incongruent    left      0
# 1         1          0    correct  0.279297    congruent    left      0
# 2         2          0    correct  0.254883    congruent    left      0
# 3         3          0    correct  0.375977  incongruent   right      0
# 4         4          0  incorrect  0.255859  incongruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.375977  incongruent   right      2
# 1244   1244          2    correct  0.351562  incongruent   right      2
# 1245   1245          2    correct  0.312500    congruent    left      2
# 1246   1246          2    correct  0.352539    congruent   right      2
# 1247   1247          2    correct  0.361328  incongruent   right      2
#
#       subject  negative_first
# 0          24            True
# 1          24            True
# 2          24            True
# 3          24            True
# 4          24            True
# ...       ...             ...
# 1243       24            True
# 1244       24            True
# 1245       24            True
# 1246       24            True
# 1247       24            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-006.tsv
#       trial  condition reaction        rt       target flanker  block  \
# 0         0          0  correct  0.540039  incongruent    left      0
# 1         1          0  correct  0.373047    congruent   right      0
# 2         2          0  correct  0.477539  incongruent   right      0
# 3         3          0  correct  0.309570    congruent    left      0
# 4         4          0  correct  0.270508    congruent    left      0
# ...     ...        ...      ...       ...          ...     ...    ...
# 1243   1243          3  correct  0.330078  incongruent    left      3
# 1244   1244          3  correct  0.323242    congruent    left      3
# 1245   1245          3  correct  0.315430    congruent    left      3
# 1246   1246          3  correct  0.324219  incongruent    left      3
# 1247   1247          3  correct  0.317383    congruent   right      3
#
#       subject  negative_first
# 0           6           False
# 1           6           False
# 2           6           False
# 3           6           False
# 4           6           False
# ...       ...             ...
# 1243        6           False
# 1244        6           False
# 1245        6           False
# 1246        6           False
# 1247        6           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-022.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0  incorrect  1.533203    congruent    left      0
# 1         1          0    correct  1.238281  incongruent    left      0
# 2         2          0    correct  0.751953    congruent   right      0
# 3         3          0    correct  0.616211  incongruent    left      0
# 4         4          0    correct  0.497070    congruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.389648  incongruent    left      2
# 1244   1244          2    correct  0.366211    congruent    left      2
# 1245   1245          2    correct  0.390625    congruent   right      2
# 1246   1246          2    correct  0.463867    congruent   right      2
# 1247   1247          2    correct  0.471680  incongruent   right      2
#
#       subject  negative_first
# 0          22            True
# 1          22            True
# 2          22            True
# 3          22            True
# 4          22            True
# ...       ...             ...
# 1243       22            True
# 1244       22            True
# 1245       22            True
# 1246       22            True
# 1247       22            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-017.tsv
#       trial  condition reaction        rt       target flanker  block  \
# 0         0          0  correct  0.612305    congruent    left      0
# 1         1          0  correct  0.476562  incongruent   right      0
# 2         2          0  correct  0.454102  incongruent   right      0
# 3         3          0  correct  0.414062    congruent   right      0
# 4         4          0  correct  0.518555  incongruent   right      0
# ...     ...        ...      ...       ...          ...     ...    ...
# 1243   1243          3  correct  0.435547  incongruent   right      3
# 1244   1244          3  correct  0.348633  incongruent    left      3
# 1245   1245          3  correct  0.291992    congruent   right      3
# 1246   1246          3  correct  0.365234  incongruent    left      3
# 1247   1247          3  correct  0.325195    congruent    left      3
#
#       subject  negative_first
# 0          17           False
# 1          17           False
# 2          17           False
# 3          17           False
# 4          17           False
# ...       ...             ...
# 1243       17           False
# 1244       17           False
# 1245       17           False
# 1246       17           False
# 1247       17           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-008.tsv
#       trial  condition reaction        rt       target flanker  block  \
# 0         0          0  correct  0.729492    congruent   right      0
# 1         1          0  correct  0.353516  incongruent    left      0
# 2         2          0  correct  0.298828    congruent   right      0
# 3         3          0  correct  0.529297  incongruent   right      0
# 4         4          0  correct  0.585938    congruent    left      0
# ...     ...        ...      ...       ...          ...     ...    ...
# 1243   1243          3  correct  0.389648  incongruent   right      3
# 1244   1244          3  correct  0.461914    congruent    left      3
# 1245   1245          3  correct  0.293945    congruent   right      3
# 1246   1246          3  correct  0.334961    congruent   right      3
# 1247   1247          3  correct  0.406250  incongruent    left      3
#
#       subject  negative_first
# 0           8           False
# 1           8           False
# 2           8           False
# 3           8           False
# 4           8           False
# ...       ...             ...
# 1243        8           False
# 1244        8           False
# 1245        8           False
# 1246        8           False
# 1247        8           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-032.tsv
#      trial  condition   reaction        rt       target flanker  block  \
# 0        0          0        NaN       NaN  incongruent    left      0
# 1        1          0  incorrect  0.251953  incongruent   right      0
# 2        2          0    correct  0.373047  incongruent   right      0
# 3        3          0    correct  0.284180    congruent   right      0
# 4        4          0    correct  0.309570    congruent   right      0
# ..     ...        ...        ...       ...          ...     ...    ...
# 915    915          2    correct  0.281250    congruent   right      2
# 916    916          2    correct  0.336914  incongruent   right      2
# 917    917          2    correct  0.313477  incongruent   right      2
# 918    918          2    correct  0.289062    congruent   right      2
# 919    919          2  incorrect  0.281250  incongruent   right      2
#
#      subject  negative_first
# 0         32            True
# 1         32            True
# 2         32            True
# 3         32            True
# 4         32            True
# ..       ...             ...
# 915       32            True
# 916       32            True
# 917       32            True
# 918       32            True
# 919       32            True
#
# [920 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-013.tsv
#       trial  condition reaction        rt       target flanker  block  \
# 0         0          0      NaN       NaN  incongruent   right      0
# 1         1          0      NaN       NaN  incongruent   right      0
# 2         2          0  correct  0.385742  incongruent    left      0
# 3         3          0  correct  0.296875    congruent    left      0
# 4         4          0  correct  0.257812    congruent    left      0
# ...     ...        ...      ...       ...          ...     ...    ...
# 1243   1243          3  correct  0.285156    congruent    left      3
# 1244   1244          3  correct  0.357422  incongruent    left      3
# 1245   1245          3  correct  0.318359  incongruent    left      3
# 1246   1246          3  correct  0.309570    congruent    left      3
# 1247   1247          3  correct  0.254883    congruent    left      3
#
#       subject  negative_first
# 0          13           False
# 1          13           False
# 2          13           False
# 3          13           False
# 4          13           False
# ...       ...             ...
# 1243       13           False
# 1244       13           False
# 1245       13           False
# 1246       13           False
# 1247       13           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-020.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.553711    congruent   right      0
# 1         1          0    correct  0.275391    congruent    left      0
# 2         2          0  incorrect  0.266602  incongruent    left      0
# 3         3          0    correct  0.275391    congruent    left      0
# 4         4          0    correct  0.347656    congruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.184570    congruent   right      2
# 1244   1244          2  incorrect  0.256836  incongruent   right      2
# 1245   1245          2  incorrect  0.265625  incongruent    left      2
# 1246   1246          2    correct  0.273438    congruent   right      2
# 1247   1247          2    correct  0.297852  incongruent    left      2
#
#       subject  negative_first
# 0          20            True
# 1          20            True
# 2          20            True
# 3          20            True
# 4          20            True
# ...       ...             ...
# 1243       20            True
# 1244       20            True
# 1245       20            True
# 1246       20            True
# 1247       20            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-004.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.549805  incongruent   right      0
# 1         1          0    correct  0.303711    congruent   right      0
# 2         2          0    correct  0.343750    congruent    left      0
# 3         3          0    correct  0.304688    congruent    left      0
# 4         4          0  incorrect  0.344727  incongruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3    correct  0.539062  incongruent   right      3
# 1244   1244          3    correct  0.546875    congruent    left      3
# 1245   1245          3    correct  0.444336  incongruent   right      3
# 1246   1246          3    correct  0.580078    congruent    left      3
# 1247   1247          3    correct  0.509766    congruent    left      3
#
#       subject  negative_first
# 0           4           False
# 1           4           False
# 2           4           False
# 3           4           False
# 4           4           False
# ...       ...             ...
# 1243        4           False
# 1244        4           False
# 1245        4           False
# 1246        4           False
# 1247        4           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-027.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.497070  incongruent   right      0
# 1         1          0    correct  0.313477    congruent   right      0
# 2         2          0  incorrect  0.307617  incongruent    left      0
# 3         3          0  incorrect  0.284180  incongruent   right      0
# 4         4          0    correct  0.260742    congruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3    correct  0.333984  incongruent    left      3
# 1244   1244          3    correct  0.232422    congruent   right      3
# 1245   1245          3    correct  0.256836    congruent   right      3
# 1246   1246          3    correct  0.521484  incongruent    left      3
# 1247   1247          3    correct  0.354492  incongruent    left      3
#
#       subject  negative_first
# 0          27           False
# 1          27           False
# 2          27           False
# 3          27           False
# 4          27           False
# ...       ...             ...
# 1243       27           False
# 1244       27           False
# 1245       27           False
# 1246       27           False
# 1247       27           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-019.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.510742    congruent    left      0
# 1         1          0    correct  0.262695    congruent   right      0
# 2         2          0    correct  0.334961    congruent    left      0
# 3         3          0  incorrect  0.262695  incongruent   right      0
# 4         4          0    correct  0.399414  incongruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3    correct  0.361328  incongruent   right      3
# 1244   1244          3    correct  0.322266  incongruent   right      3
# 1245   1245          3    correct  0.265625    congruent    left      3
# 1246   1246          3    correct  0.354492  incongruent   right      3
# 1247   1247          3    correct  0.330078  incongruent    left      3
#
#       subject  negative_first
# 0          19           False
# 1          19           False
# 2          19           False
# 3          19           False
# 4          19           False
# ...       ...             ...
# 1243       19           False
# 1244       19           False
# 1245       19           False
# 1246       19           False
# 1247       19           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-028.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.717773  incongruent    left      0
# 1         1          0    correct  0.375977    congruent   right      0
# 2         2          0    correct  0.319336    congruent    left      0
# 3         3          0    correct  0.440430  incongruent   right      0
# 4         4          0    correct  0.304688    congruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.277344    congruent   right      2
# 1244   1244          2    correct  0.381836  incongruent    left      2
# 1245   1245          2    correct  0.358398  incongruent   right      2
# 1246   1246          2  incorrect  0.607422  incongruent    left      2
# 1247   1247          2    correct  0.311523    congruent   right      2
#
#       subject  negative_first
# 0          28            True
# 1          28            True
# 2          28            True
# 3          28            True
# 4          28            True
# ...       ...             ...
# 1243       28            True
# 1244       28            True
# 1245       28            True
# 1246       28            True
# 1247       28            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-009.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0        NaN       NaN    congruent    left      0
# 1         1          0    correct  0.442383    congruent   right      0
# 2         2          0    correct  0.387695  incongruent    left      0
# 3         3          0  incorrect  0.107422    congruent   right      0
# 4         4          0  incorrect  0.116211  incongruent   right      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.436523  incongruent   right      2
# 1244   1244          2    correct  0.492188    congruent    left      2
# 1245   1245          2    correct  0.357422    congruent    left      2
# 1246   1246          2    correct  0.413086  incongruent   right      2
# 1247   1247          2    correct  0.374023  incongruent   right      2
#
#       subject  negative_first
# 0           9            True
# 1           9            True
# 2           9            True
# 3           9            True
# 4           9            True
# ...       ...             ...
# 1243        9            True
# 1244        9            True
# 1245        9            True
# 1246        9            True
# 1247        9            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-015.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0        NaN       NaN  incongruent   right      0
# 1         1          0  incorrect  0.059570  incongruent    left      0
# 2         2          0    correct  0.387695    congruent    left      0
# 3         3          0    correct  0.299805    congruent   right      0
# 4         4          0    correct  0.436523  incongruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3    correct  0.384766  incongruent   right      3
# 1244   1244          3    correct  0.393555  incongruent   right      3
# 1245   1245          3    correct  0.305664    congruent    left      3
# 1246   1246          3    correct  0.330078    congruent   right      3
# 1247   1247          3  incorrect  0.290039  incongruent    left      3
#
#       subject  negative_first
# 0          15           False
# 1          15           False
# 2          15           False
# 3          15           False
# 4          15           False
# ...       ...             ...
# 1243       15           False
# 1244       15           False
# 1245       15           False
# 1246       15           False
# 1247       15           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-018.tsv
#       trial  condition reaction        rt       target flanker  block  \
# 0         0          0  correct  1.285156    congruent    left      0
# 1         1          0  correct  0.510742  incongruent    left      0
# 2         2          0  correct  0.455078  incongruent    left      0
# 3         3          0  correct  0.542969    congruent   right      0
# 4         4          0  correct  0.280273    congruent    left      0
# ...     ...        ...      ...       ...          ...     ...    ...
# 1243   1243          2  correct  0.415039  incongruent    left      2
# 1244   1244          2  correct  0.326172    congruent    left      2
# 1245   1245          2  correct  0.447266  incongruent   right      2
# 1246   1246          2  correct  0.406250  incongruent    left      2
# 1247   1247          2  correct  0.382812  incongruent    left      2
#
#       subject  negative_first
# 0          18            True
# 1          18            True
# 2          18            True
# 3          18            True
# 4          18            True
# ...       ...             ...
# 1243       18            True
# 1244       18            True
# 1245       18            True
# 1246       18            True
# 1247       18            True
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-023.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  0.725586    congruent   right      0
# 1         1          0    correct  0.542969  incongruent   right      0
# 2         2          0    correct  0.390625  incongruent   right      0
# 3         3          0    correct  0.272461    congruent   right      0
# 4         4          0    correct  0.295898    congruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          3  incorrect  0.202148  incongruent    left      3
# 1244   1244          3  incorrect  0.242188  incongruent   right      3
# 1245   1245          3    correct  0.235352    congruent   right      3
# 1246   1246          3    correct  0.227539    congruent    left      3
# 1247   1247          3    correct  0.299805    congruent    left      3
#
#       subject  negative_first
# 0          23           False
# 1          23           False
# 2          23           False
# 3          23           False
# 4          23           False
# ...       ...             ...
# 1243       23           False
# 1244       23           False
# 1245       23           False
# 1246       23           False
# 1247       23           False
#
# [1248 rows x 9 columns]
# /home/michael/data/derivatives/results/dataframes/debugging_rt_data_sub_x.tsv
# no, no
#       trial  condition   reaction        rt       target flanker  block  \
# 937     937          3    correct  0.387695  incongruent   right      3
# 834     834          2    correct  0.355469  incongruent   right      2
# 833     833          2    correct  0.328125  incongruent   right      2
# 832     832          2    correct  0.347656  incongruent   right      2
# 831     831          2    correct  0.255859    congruent    left      2
# ...     ...        ...        ...       ...          ...     ...    ...
# 801     801          2    correct  0.269531    congruent   right      2
# 802     802          2    correct  0.374023  incongruent    left      2
# 803     803          2    correct  0.270508    congruent   right      2
# 805     805          2  incorrect  0.271484  incongruent   right      2
# 1057   1057          3    correct  0.336914    congruent    left      3
#
#       subject  negative_first
# 937         2           False
# 834         2           False
# 833         2           False
# 832         2           False
# 831         2           False
# ...       ...             ...
# 801        38           False
# 802        38           False
# 803        38           False
# 805        38           False
# 1057       38           False
#
# [39211 rows x 9 columns]

# %%
#rt_df.to_csv('/home/michael/Desktop/reaction_times.tsv', sep='\t', index=False)

# %%
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#    display(rt_df)

# %%
# group by incongruent or congruent target in flanker-task
grouped = rt_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        rt_congruent_df = group
    elif name == 'incongruent':
        rt_incongruent_df = group
        
grouped = rt_congruent_df.groupby('reaction')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'correct':
        rt_correct_df_congruent = group
    elif name == 'incorrect':
        rt_incorrect_df_congruent = group
        
        
grouped = rt_incongruent_df.groupby('reaction')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'correct':
        rt_correct_df_incongruent = group
    elif name == 'incorrect':
        rt_incorrect_df_incongruent = group

# %%
rt_incorrect_df_congruent
# Out:
#      trial  condition   reaction        rt     target flanker  block  subject  \
# 427    427          1  incorrect  0.396484  congruent    left      1        7
# 433    433          1  incorrect  0.398438  congruent    left      1        7
# 477    477          3  incorrect  0.353516  congruent    left      3        7
# 914    914          2  incorrect  0.432617  congruent   right      2        7
# 341    341          1  incorrect  0.278320  congruent    left      1       11
# ..     ...        ...        ...       ...        ...     ...    ...      ...
# 773    773          2  incorrect  0.242188  congruent    left      2       23
# 873    873          3  incorrect  0.235352  congruent    left      3       23
# 910    910          3  incorrect  0.305664  congruent    left      3       23
# 912    912          3  incorrect  0.322266  congruent    left      3       23
# 951    951          3  incorrect  0.281250  congruent   right      3       23
#
#      negative_first
# 427            True
# 433            True
# 477            True
# 914            True
# 341           False
# ..              ...
# 773           False
# 873           False
# 910           False
# 912           False
# 951           False
#
# [215 rows x 9 columns]

# %%
rt_incorrect_df_congruent['reaction'].count()
# Out:
# 215

# %%
rt_incorrect_df_incongruent['reaction'].count()
# Out:
# 2450

# %%
# groupby correct or incorrect answer 

grouped = rt_df.groupby('reaction')


# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'correct':
        rt_correct_df = group
    elif name == 'incorrect':
        rt_incorrect_df = group
        
grouped = rt_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_set = group
    elif name == 1:
        rt_baseline = group
    elif name == 2:
        rt_positive = group
    elif name == 3:
        rt_negative = group
        
        
baseline_mean = rt_baseline['rt'].mean()
positive_mean = rt_positive['rt'].mean()
negative_mean = rt_negative['rt'].mean()

rts_df = pd.DataFrame()
rts_df['baseline'] = [rt_baseline['rt'].mean()]
rts_df['positive'] = rt_positive['rt'].mean()
rts_df['negative'] = rt_negative['rt'].mean()

rts_df = rts_df.T.rename(columns={0: 'mean rt'})

rts_df['sem'] = [rt_baseline['rt'].sem(),
                       rt_positive['rt'].sem(),
                       rt_negative['rt'].sem()]
        
# group by incongruent or congruent target in flanker-task
grouped = rt_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        rt_incongruent_df = group
    elif name == 'incongruent':
        rt_congruent_df = group
        
### Groupby experimental block 

grouped = rt_incongruent_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_training_set = group
    elif name == 1:
        incongruent_rt_baseline = group
    elif name == 2:
        incongruent_rt_positive = group
    elif name == 3:
        incongruent_rt_negative = group
        
grouped = rt_incongruent_df.groupby('condition')

incongruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_training_set = group
    else:
        incongruent_no_trainig = incongruent_no_trainig.append(group)
        
grouped = rt_congruent_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    elif name == 1:
        congruent_rt_baseline = group
    elif name == 2:
        congruent_rt_positive = group
    elif name == 3:
        congruent_rt_negative = group
        

grouped = rt_congruent_df.groupby('condition')

congruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        congruent_no_trainig = congruent_no_trainig.append(group)
        
rt_congruent = pd.DataFrame()
rt_congruent['baseline'] = [congruent_rt_baseline['rt'].mean()]
rt_congruent['positive'] = congruent_rt_positive['rt'].mean()
rt_congruent['negative'] = congruent_rt_negative['rt'].mean()
rt_congruent


rt_congruent = rt_congruent.T.rename(columns={0: 'mean rt'})

rt_congruent['sem'] = [congruent_rt_baseline['rt'].sem(), congruent_rt_positive['rt'].sem(),
                       congruent_rt_negative['rt'].sem()]

rt_incongruent = pd.DataFrame()
rt_incongruent['baseline'] = [incongruent_rt_baseline['rt'].mean()]
rt_incongruent['positive'] = incongruent_rt_positive['rt'].mean()
rt_incongruent['negative'] = incongruent_rt_negative['rt'].mean()

rt_incongruent = rt_incongruent.T.rename(columns={0: 'mean rt'})

rt_incongruent['sem'] = [incongruent_rt_baseline['rt'].sem(), incongruent_rt_positive['rt'].sem(),
                         incongruent_rt_negative['rt'].sem()]

# %%
list_rt_df = [rt_incongruent, rt_congruent]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    #print(idx)
    #print(df['mean rt'].to_numpy()[0])
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'rt_incongruent'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='rt_incongruent')
        x_arr = x_arr -.1
    elif idx == 1:
        cond_temp = 'rt_congruent'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='rt_congruent')
        x_arr = x_arr
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    

fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('congruent vs incongruent')

plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
grouped = rt_df.groupby('negative_first')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == True:
        negative_first_df = group
    elif name == False:
        positive_first_df = group
        
# groupby experiment block
        
grouped = negative_first_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_neg_set = group
    elif name == 1:
        rt_neg_baseline = group
    elif name == 2:
        rt_neg_positive = group
    elif name == 3:
        rt_neg_negative = group
        
negative_first = pd.DataFrame()

negative_first['baseline'] = [rt_neg_baseline['rt'].mean()]
negative_first['positive'] = rt_neg_positive['rt'].mean()
negative_first['negative'] = rt_neg_negative['rt'].mean()

negative_first = negative_first.T.rename(columns={0: 'mean rt'})


negative_first['sem'] = [rt_neg_baseline['rt'].sem(), 
                                   rt_neg_positive['rt'].sem(),
                                   rt_neg_negative['rt'].sem()]


grouped = positive_first_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_pos_set = group
    elif name == 1:
        rt_pos_baseline = group
    elif name == 2:
        rt_pos_positive = group
    elif name == 3:
        rt_pos_negative = group
        
positive_first = pd.DataFrame()

positive_first['baseline'] = [rt_pos_baseline['rt'].mean()]
positive_first['positive'] = rt_pos_positive['rt'].mean()
positive_first['negative'] = rt_pos_negative['rt'].mean()

positive_first = positive_first.T.rename(columns={0: 'mean rt'})


positive_first['sem'] = [rt_pos_baseline['rt'].sem(), 
                                   rt_pos_positive['rt'].sem(),
                                   rt_pos_negative['rt'].sem()]

# %%
sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)

ax.plot([positive_first_df['rt'].mean(), negative_first_df['rt'].mean()], color='r')



fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[2] = 'Negative first'
labels[1] = 'Positive first'

ax.set_xticklabels(labels)
ax.set_xticklabels(labels)

# draw custom error bars
plt.plot([0, 0], [(positive_first_df['rt'].mean() + positive_first_df['rt'].sem()),
                  (positive_first_df['rt'].mean() - positive_first_df['rt'].sem())], 'r', lw=0.5)

plt.plot([-0.02, 0.02], [(positive_first_df['rt'].mean() + positive_first_df['rt'].sem()),
                  (positive_first_df['rt'].mean() + positive_first_df['rt'].sem())], 'r', lw=0.5)

plt.plot([-0.02, 0.02], [(positive_first_df['rt'].mean() - positive_first_df['rt'].sem()),
                  (positive_first_df['rt'].mean() - positive_first_df['rt'].sem())], 'r', lw=0.5)


plt.plot([1, 1], [(negative_first_df['rt'].mean() + negative_first_df['rt'].sem()),
                  (negative_first_df['rt'].mean() - negative_first_df['rt'].sem())], 'r', lw=0.5)

plt.plot([0.98, 1.02], [(negative_first_df['rt'].mean() - negative_first_df['rt'].sem()),
                  (negative_first_df['rt'].mean() - negative_first_df['rt'].sem())], 'r', lw=0.5)

plt.plot([0.98, 1.02], [(negative_first_df['rt'].mean() + negative_first_df['rt'].sem()),
                  (negative_first_df['rt'].mean() + negative_first_df['rt'].sem())], 'r', lw=0.5)



plt.ylim(0.2, 0.5)


plt.show()

# %%
grouped = positive_first_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        positive_first_rt_incongruent_df = group
    elif name == 'incongruent':
        positive_first_rt_congruent_df = group
        
grouped = negative_first_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        negative_first_rt_incongruent_df = group
    elif name == 'incongruent':
        negative_first_rt_congruent_df = group

# %%
grouped = negative_first_rt_incongruent_df.groupby('condition')

negative_first_incongruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        negative_first_incongruent_no_trainig = negative_first_incongruent_no_trainig.append(group)



grouped = negative_first_incongruent_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_training_set = group
    elif name == 1:
        negative_first_incongruent_rt_baseline = group
    elif name == 2:
        negative_first_incongruent_rt_positive = group
    elif name == 3:
        negative_first_incongruent_rt_negative = group
        
        
negative_first_df_rt_incongruent = pd.DataFrame()
negative_first_df_rt_incongruent['baseline'] = [negative_first_incongruent_rt_baseline['rt'].mean()]
negative_first_df_rt_incongruent['positive'] = negative_first_incongruent_rt_positive['rt'].mean()
negative_first_df_rt_incongruent['negative'] = negative_first_incongruent_rt_negative['rt'].mean()


negative_first_df_rt_incongruent = negative_first_df_rt_incongruent.T.rename(columns={0: 'mean rt'})

negative_first_df_rt_incongruent['sem'] = [negative_first_incongruent_rt_baseline['rt'].sem(),
                                           negative_first_incongruent_rt_positive['rt'].sem(),
                                           negative_first_incongruent_rt_negative['rt'].sem()]


## Congruent

        
grouped = negative_first_rt_congruent_df.groupby('condition')

negative_first_congruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        negative_first_congruent_no_trainig = negative_first_congruent_no_trainig.append(group)



grouped = negative_first_congruent_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    elif name == 1:
        negative_first_df_congruent_rt_baseline = group
    elif name == 2:
        negative_first_df_congruent_rt_positive = group
    elif name == 3:
        negative_first_df_congruent_rt_negative = group
        
negative_first_df_rt_congruent = pd.DataFrame()
negative_first_df_rt_congruent['baseline'] = [negative_first_df_congruent_rt_baseline['rt'].mean()]
negative_first_df_rt_congruent['positive'] = negative_first_df_congruent_rt_positive['rt'].mean()
negative_first_df_rt_congruent['negative'] = negative_first_df_congruent_rt_negative['rt'].mean()
rt_congruent


negative_first_df_rt_congruent = negative_first_df_rt_congruent.T.rename(columns={0: 'mean rt'})

negative_first_df_rt_congruent['sem'] = [negative_first_df_congruent_rt_baseline['rt'].sem(),
                                         negative_first_df_congruent_rt_positive['rt'].sem(),
                                         negative_first_df_congruent_rt_negative['rt'].sem()]

# %%
grouped = positive_first_rt_incongruent_df.groupby('condition')
positive_first_incongruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        positive_first_incongruent_no_trainig = positive_first_incongruent_no_trainig.append(group)



grouped = positive_first_incongruent_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_training_set = group
    elif name == 1:
        positive_first_incongruent_rt_baseline = group
    elif name == 2:
        positive_first_incongruent_rt_positive = group
    elif name == 3:
        positive_first_incongruent_rt_negative = group
        
        
positive_first_df_rt_incongruent = pd.DataFrame()
positive_first_df_rt_incongruent['baseline'] = [positive_first_incongruent_rt_baseline['rt'].mean()]
positive_first_df_rt_incongruent['positive'] = positive_first_incongruent_rt_positive['rt'].mean()
positive_first_df_rt_incongruent['negative'] = positive_first_incongruent_rt_negative['rt'].mean()
rt_congruent


positive_first_df_rt_incongruent = positive_first_df_rt_incongruent.T.rename(columns={0: 'mean rt'})

positive_first_df_rt_incongruent['sem'] = [positive_first_incongruent_rt_baseline['rt'].sem(),
                                           positive_first_incongruent_rt_positive['rt'].sem(),
                                           positive_first_incongruent_rt_negative['rt'].sem()]


## Incongruent

        
grouped = positive_first_rt_congruent_df.groupby('condition')

positive_first_congruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        positive_first_congruent_no_trainig = positive_first_congruent_no_trainig.append(group)



grouped = positive_first_congruent_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    elif name == 1:
        positive_first_df_congruent_rt_baseline = group
    elif name == 2:
        positive_first_df_congruent_rt_positive = group
    elif name == 3:
        positive_first_df_congruent_rt_negative = group
        
positive_first_df_rt_congruent = pd.DataFrame()
positive_first_df_rt_congruent['baseline'] = [positive_first_df_congruent_rt_baseline['rt'].mean()]
positive_first_df_rt_congruent['positive'] = positive_first_df_congruent_rt_positive['rt'].mean()
positive_first_df_rt_congruent['negative'] = positive_first_df_congruent_rt_negative['rt'].mean()
rt_congruent


positive_first_df_rt_congruent = positive_first_df_rt_congruent.T.rename(columns={0: 'mean rt'})

positive_first_df_rt_congruent['sem'] = [positive_first_df_congruent_rt_baseline['rt'].sem(), positive_first_df_congruent_rt_positive['rt'].sem(),
                       positive_first_df_congruent_rt_negative['rt'].sem()]

# %%
list_rt_df = [positive_first_df_rt_incongruent, positive_first_df_rt_congruent,
              negative_first_df_rt_incongruent, negative_first_df_rt_congruent]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    #print(idx)
    #print(df['mean rt'].to_numpy()[0])
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'positive_first_df_rt_incongruent'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent positive first')
        x_arr = x_arr -.1
    elif idx == 1:
        cond_temp = 'positive_first_df_rt_congruent'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent positive first')
        x_arr = x_arr
    elif idx == 2:
        cond_temp = 'negative_first_df_rt_incongruent'
        color_temp = 'maroon'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent negative first')
        x_arr = x_arr +.1
    elif idx == 3:
        cond_temp = 'negative_first_df_rt_incongruent'
        color_temp = 'midnightblue'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent negative first')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    

fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('positive vs negative first & congruent vs congruent')
plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
list_rt_df = [negative_first_df_rt_incongruent, negative_first_df_rt_congruent]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):

    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'negative_first_df_rt_incongruent'
        color_temp = 'maroon'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent negative first')
        x_arr = x_arr
    elif idx == 1:
        cond_temp = 'negative_first_df_rt_incongruent'
        color_temp = 'midnightblue'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent negative first')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    
fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)
plt.title('negative first incongruent vs congruent')
plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
list_rt_df = [positive_first_df_rt_incongruent, positive_first_df_rt_congruent]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'positive_first_df_rt_incongruent'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent positive first')
        x_arr = x_arr
    elif idx == 1:
        cond_temp = 'positive_first_df_rt_congruent'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent positive first')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[2]-0.01, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    
fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[3] = 'Negative'
labels[2] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)
plt.title('positive first incongruent vs congruent')
plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %% [markdown]
# ## Correct Trials

# %%
##### Correct Trials



# groupby correct or incorrect answer 

grouped = rt_df.groupby('reaction')


# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'correct':
        rt_correct_df = group
    elif name == 'incorrect':
        rt_incorrect_df = group

## groupby condition

grouped = rt_correct_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_set_correct = group
    elif name == 1:
        rt_baseline_correct = group
    elif name == 2:
        rt_positive_correct = group
    elif name == 3:
        rt_negative_correct = group
        
        
baseline_mean_correct = rt_baseline_correct['rt'].mean()
positive_mean_correct = rt_positive_correct['rt'].mean()
negative_mean_correct = rt_negative_correct['rt'].mean()
        
rt_correct = pd.DataFrame()
rt_correct['baseline'] = [rt_baseline_correct['rt'].mean()]
rt_correct['positive'] = rt_positive_correct['rt'].mean()
rt_correct['negative'] = rt_negative_correct['rt'].mean()

rt_correct = rt_correct.T.rename(columns={0: 'mean rt'})

rt_correct['sem'] = [rt_baseline_correct['rt'].sem(),
                       rt_positive_correct['rt'].sem(),
                       rt_negative_correct['rt'].sem()]
        
# group by incongruent or congruent target in flanker-task
grouped = rt_correct_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        rt_incongruent_correct_df = group
    elif name == 'incongruent':
        rt_congruent_correct_df = group
        
### Groupby experimental block 

grouped = rt_incongruent_correct_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_correct_training_set = group
    elif name == 1:
        incongruent_correct_rt_baseline = group
    elif name == 2:
        incongruent_correct_rt_positive = group
    elif name == 3:
        incongruent_correct_rt_negative = group
        
grouped = rt_incongruent_correct_df.groupby('condition')

incongruent_correct_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_correct_training_set = group
    else:
        incongruent_correct_no_trainig = incongruent_correct_no_trainig.append(group)
        
grouped = rt_congruent_correct_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_correct_training_set = group
    elif name == 1:
        congruent_correct_rt_baseline = group
    elif name == 2:
        congruent_correct_rt_positive = group
    elif name == 3:
        congruent_correct_rt_negative = group
        

grouped = rt_congruent_correct_df.groupby('condition')

congruent_correct_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_correct_training_set = group
    else:
        congruent_correct_no_trainig = congruent_correct_no_trainig.append(group)
        
rt_congruent_correct = pd.DataFrame()
rt_congruent_correct['baseline'] = [congruent_correct_rt_baseline['rt'].mean()]
rt_congruent_correct['positive'] = congruent_correct_rt_positive['rt'].mean()
rt_congruent_correct['negative'] = congruent_correct_rt_negative['rt'].mean()


rt_congruent_correct = rt_congruent_correct.T.rename(columns={0: 'mean rt'})

rt_congruent_correct['sem'] = [congruent_correct_rt_baseline['rt'].sem(), congruent_correct_rt_positive['rt'].sem(),
                       congruent_correct_rt_negative['rt'].sem()]

rt_incongruent_correct = pd.DataFrame()
rt_incongruent_correct['baseline'] = [incongruent_correct_rt_baseline['rt'].mean()]
rt_incongruent_correct['positive'] = incongruent_correct_rt_positive['rt'].mean()
rt_incongruent_correct['negative'] = incongruent_correct_rt_negative['rt'].mean()

rt_incongruent_correct = rt_incongruent_correct.T.rename(columns={0: 'mean rt'})

rt_incongruent_correct['sem'] = [incongruent_correct_rt_baseline['rt'].sem(),
                                 incongruent_correct_rt_positive['rt'].sem(),
                                 incongruent_correct_rt_negative['rt'].sem()]


##mgroupby experiment condition

grouped = rt_correct_df.groupby('negative_first')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == True:
        negative_first_correct_df = group
    elif name == False:
        positive_first_correct_df = group
        
# groupby experiment block
        
grouped = negative_first_correct_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_neg_set_correct = group
    elif name == 1:
        rt_neg_baseline_correct = group
    elif name == 2:
        rt_neg_positive_correct = group
    elif name == 3:
        rt_neg_negative_correct = group
        
baseline_mean_correct = rt_baseline_correct['rt'].mean()
positive_mean_correct = rt_positive_correct['rt'].mean()
negative_mean_correct = rt_negative_correct['rt'].mean()
        
negative_first_correct = pd.DataFrame()

negative_first_correct['baseline'] = [rt_neg_baseline_correct['rt'].mean()]
negative_first_correct['positive'] = rt_neg_positive_correct['rt'].mean()
negative_first_correct['negative'] = rt_neg_negative_correct['rt'].mean()

negative_first_correct = negative_first_correct.T.rename(columns={0: 'mean rt'})


negative_first_correct['sem'] = [rt_neg_baseline_correct['rt'].sem(), 
                                   rt_neg_positive_correct['rt'].sem(),
                                   rt_neg_negative_correct['rt'].sem()]


grouped = positive_first_correct_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_pos_set_correct = group
    elif name == 1:
        rt_pos_baseline_correct = group
    elif name == 2:
        rt_pos_positive_correct = group
    elif name == 3:
        rt_pos_negative_correct = group
        
positive_first_correct = pd.DataFrame()

positive_first_correct['baseline'] = [rt_pos_baseline_correct['rt'].mean()]
positive_first_correct['positive'] = rt_pos_positive_correct['rt'].mean()
positive_first_correct['negative'] = rt_pos_negative_correct['rt'].mean()

positive_first_correct = positive_first_correct.T.rename(columns={0: 'mean rt'})


positive_first_correct['sem'] = [rt_pos_baseline_correct['rt'].sem(), 
                                   rt_neg_positive_correct['rt'].sem(),
                                   rt_pos_negative_correct['rt'].sem()]


        
        
grouped = positive_first_correct_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        positive_first_rt_incongruent_correct_df = group
    elif name == 'incongruent':
        positive_first_rt_congruent_correct_df = group
        
grouped = negative_first_correct_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        negative_first_rt_incongruent_correct_df = group
    elif name == 'incongruent':
        negative_first_rt_congruent_correct_df = group

grouped = negative_first_rt_incongruent_correct_df.groupby('condition')

negative_first_incongruent_correct_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_correct_set = group
    else:
        negative_first_incongruent_correct_no_trainig = negative_first_incongruent_correct_no_trainig.append(group)



grouped = negative_first_incongruent_correct_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_correct_training_set = group
    elif name == 1:
        negative_first_incongruent_correct_rt_baseline = group
    elif name == 2:
        negative_first_incongruent_correct_rt_positive = group
    elif name == 3:
        negative_first_incongruent_correct_rt_negative = group
        
        
negative_first_df_rt_incongruent_correct = pd.DataFrame()
negative_first_df_rt_incongruent_correct['baseline'] = [negative_first_incongruent_correct_rt_baseline['rt'].mean()]
negative_first_df_rt_incongruent_correct['positive'] = negative_first_incongruent_correct_rt_positive['rt'].mean()
negative_first_df_rt_incongruent_correct['negative'] = negative_first_incongruent_correct_rt_negative['rt'].mean()
rt_congruent


negative_first_df_rt_incongruent_correct = negative_first_df_rt_incongruent_correct.T.rename(columns={0: 'mean rt'})

negative_first_df_rt_incongruent_correct['sem'] = [negative_first_incongruent_correct_rt_baseline['rt'].sem(),
                                           negative_first_incongruent_correct_rt_positive['rt'].sem(),
                                           negative_first_incongruent_correct_rt_negative['rt'].sem()]


## Congruent

        
grouped = negative_first_rt_congruent_correct_df.groupby('condition')

negative_first_congruent_correct_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_correct_training_set = group
    else:
        negative_first_congruent_correct_no_trainig = negative_first_congruent_correct_no_trainig.append(group)



grouped = negative_first_congruent_correct_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_correct_training_set = group
    elif name == 1:
        negative_first_df_congruent_correct_rt_baseline = group
    elif name == 2:
        negative_first_df_congruent_correct_rt_positive = group
    elif name == 3:
        negative_first_df_congruent_correct_rt_negative = group
        
negative_first_df_rt_congruent_correct = pd.DataFrame()
negative_first_df_rt_congruent_correct['baseline'] = [negative_first_df_congruent_correct_rt_baseline['rt'].mean()]
negative_first_df_rt_congruent_correct['positive'] = negative_first_df_congruent_correct_rt_positive['rt'].mean()
negative_first_df_rt_congruent_correct['negative'] = negative_first_df_congruent_correct_rt_negative['rt'].mean()
rt_congruent


negative_first_df_rt_congruent_correct = negative_first_df_rt_congruent_correct.T.rename(columns={0: 'mean rt'})

negative_first_df_rt_congruent_correct['sem'] = [negative_first_df_congruent_correct_rt_baseline['rt'].sem(),
                                         negative_first_df_congruent_correct_rt_positive['rt'].sem(),
                                         negative_first_df_congruent_correct_rt_negative['rt'].sem()]

grouped = positive_first_rt_incongruent_correct_df.groupby('condition')
positive_first_incongruent_correct_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_correct_training_set = group
    else:
        positive_first_incongruent_correct_no_trainig = positive_first_incongruent_correct_no_trainig.append(group)



grouped = positive_first_incongruent_correct_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_correct_training_set = group
    elif name == 1:
        positive_first_incongruent_correct_rt_baseline = group
    elif name == 2:
        positive_first_incongruent_correct_rt_positive = group
    elif name == 3:
        positive_first_incongruent_correct_rt_negative = group
        
        
positive_first_df_rt_incongruent_correct = pd.DataFrame()
positive_first_df_rt_incongruent_correct['baseline'] = [positive_first_incongruent_correct_rt_baseline['rt'].mean()]
positive_first_df_rt_incongruent_correct['positive'] = positive_first_incongruent_correct_rt_positive['rt'].mean()
positive_first_df_rt_incongruent_correct['negative'] = positive_first_incongruent_correct_rt_negative['rt'].mean()
rt_congruent


positive_first_df_rt_incongruent_correct = positive_first_df_rt_incongruent_correct.T.rename(columns={0: 'mean rt'})

positive_first_df_rt_incongruent_correct['sem'] = [positive_first_incongruent_correct_rt_baseline['rt'].sem(),
                                           positive_first_incongruent_correct_rt_positive['rt'].sem(),
                                           positive_first_incongruent_correct_rt_negative['rt'].sem()]


## Incongruent

        
grouped = positive_first_rt_congruent_correct_df.groupby('condition')

positive_first_congruent_correct_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_correct_training_set = group
    else:
        positive_first_congruent_correct_no_trainig = positive_first_congruent_correct_no_trainig.append(group)



grouped = positive_first_congruent_correct_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_correct_training_set = group
    elif name == 1:
        positive_first_df_congruent_correct_rt_baseline = group
    elif name == 2:
        positive_first_df_congruent_correct_rt_positive = group
    elif name == 3:
        positive_first_df_congruent_correct_rt_negative = group
        
positive_first_df_rt_congruent_correct = pd.DataFrame()
positive_first_df_rt_congruent_correct['baseline'] = [positive_first_df_congruent_correct_rt_baseline['rt'].mean()]
positive_first_df_rt_congruent_correct['positive'] = positive_first_df_congruent_correct_rt_positive['rt'].mean()
positive_first_df_rt_congruent_correct['negative'] = positive_first_df_congruent_correct_rt_negative['rt'].mean()
rt_congruent


positive_first_df_rt_congruent_correct = positive_first_df_rt_congruent_correct.T.rename(columns={0: 'mean rt'})

positive_first_df_rt_congruent_correct['sem'] = [positive_first_df_congruent_correct_rt_baseline['rt'].sem(),
                                                 positive_first_df_congruent_correct_rt_positive['rt'].sem(),
                                                 positive_first_df_congruent_correct_rt_negative['rt'].sem()]

# %%
list_rt_df = [positive_first_df_rt_incongruent_correct, positive_first_df_rt_congruent_correct,
              negative_first_df_rt_incongruent_correct, negative_first_df_rt_congruent_correct]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    #print(idx)
    #print(df['mean rt'].to_numpy()[0])
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'positive_first_df_rt_incongruent_correct'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent positive first_correct')
        x_arr = x_arr -.1
    elif idx == 1:
        cond_temp = 'positive_first_df_rt_congruent'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent positive first_correct')
        x_arr = x_arr
    elif idx == 2:
        cond_temp = 'negative_first_df_rt_incongruent'
        color_temp = 'maroon'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent negative first_correct')
        x_arr = x_arr +.1
    elif idx == 3:
        cond_temp = 'negative_first_df_rt_incongruent'
        color_temp = 'midnightblue'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent negative first_correct')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    

fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('correct trials: positive vs negative first & congruent vs incongruent')

plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
rt_correct
# Out:
#            mean rt       sem
# baseline  0.359348  0.000847
# positive  0.347083  0.000771
# negative  0.349691  0.000781

# %%
list_rt_df = [negative_first_df_rt_incongruent_correct, negative_first_df_rt_congruent_correct]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):

    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'negative_first_df_rt_incongruent_correct'
        color_temp = 'maroon'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent negative first_correct')
        x_arr = x_arr
    elif idx == 1:
        cond_temp = 'negative_first_df_rt_incongruent_correct'
        color_temp = 'midnightblue'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent negative first_correct')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    
fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)
plt.title('correct trials: negative first & congruent vs incongruent')

plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
positive_first_df_rt_incongruent_correct
# Out:
#            mean rt       sem
# baseline  0.320454  0.001549
# positive  0.309961  0.001442
# negative  0.313994  0.001486

# %%
df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]
# Out:
# 0.40138771459315076

# %%
df['mean rt'].to_numpy()[2]
# Out:
# 0.39983137156072107

# %%
list_rt_df = [positive_first_df_rt_incongruent_correct, positive_first_df_rt_congruent_correct]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'positive_first_df_rt_incongruent_correct'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent positive first_correct')
        x_arr = x_arr
    elif idx == 1:
        cond_temp = 'positive_first_df_rt_congruent_correct'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent positive first_correct')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[2]-0.01, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    
fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[3] = 'Negative'
labels[2] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)
plt.title('correct trials: positive first & congruent vs incongruent')
plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %% [markdown]
# ## Inorrect Trials

# %%
##### Incorrect Trials

# groupby correct or incorrect answer 

grouped = rt_df.groupby('reaction')


# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'correct':
        rt_correct_df = group
    elif name == 'incorrect':
        rt_incorrect_df = group

## groupby condition

grouped = rt_incorrect_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_set_incorrect = group
    elif name == 1:
        rt_baseline_incorrect = group
    elif name == 2:
        rt_positive_incorrect = group
    elif name == 3:
        rt_negative_incorrect = group
        
        
baseline_mean_incorrect = rt_baseline_incorrect['rt'].mean()
positive_mean_incorrect = rt_positive_incorrect['rt'].mean()
negative_mean_incorrect = rt_negative_incorrect['rt'].mean()

rt_incorrect = pd.DataFrame()
rt_incorrect['baseline'] = [rt_baseline_incorrect['rt'].mean()]
rt_incorrect['positive'] = rt_positive_incorrect['rt'].mean()
rt_incorrect['negative'] = rt_negative_incorrect['rt'].mean()

rt_incorrect = rt_incorrect.T.rename(columns={0: 'mean rt'})

rt_incorrect['sem'] = [rt_baseline_incorrect['rt'].sem(),
                       rt_positive_incorrect['rt'].sem(),
                       rt_negative_incorrect['rt'].sem()]


# group by incongruent or congruent target in flanker-task
grouped = rt_incorrect_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        rt_incongruent_incorrect_df = group
    elif name == 'incongruent':
        rt_congruent_incorrect_df = group

        
### Groupby experimental block 

grouped = rt_incongruent_incorrect_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_incorrect_training_set = group
    elif name == 1:
        incongruent_incorrect_rt_baseline = group
    elif name == 2:
        incongruent_incorrect_rt_positive = group
    elif name == 3:
        incongruent_incorrect_rt_negative = group
        
grouped = rt_incongruent_incorrect_df.groupby('condition')

incongruent_incorrect_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_incorrect_training_set = group
    else:
        incongruent_incorrect_no_trainig = incongruent_incorrect_no_trainig.append(group)
        
grouped = rt_congruent_incorrect_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_incorrect_training_set = group
    elif name == 1:
        congruent_incorrect_rt_baseline = group
    elif name == 2:
        congruent_incorrect_rt_positive = group
    elif name == 3:
        congruent_incorrect_rt_negative = group
        

grouped = rt_congruent_incorrect_df.groupby('condition')

congruent_incorrect_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_incorrect_training_set = group
    else:
        congruent_incorrect_no_trainig = congruent_incorrect_no_trainig.append(group)


rt_congruent_incorrect = pd.DataFrame()
rt_congruent_incorrect['baseline'] = [congruent_incorrect_rt_baseline['rt'].mean()]
rt_congruent_incorrect['positive'] = congruent_incorrect_rt_positive['rt'].mean()
rt_congruent_incorrect['negative'] = congruent_incorrect_rt_negative['rt'].mean()


rt_congruent_incorrect = rt_congruent_incorrect.T.rename(columns={0: 'mean rt'})

rt_congruent_incorrect['sem'] = [congruent_incorrect_rt_baseline['rt'].sem(),
                                 congruent_incorrect_rt_positive['rt'].sem(),
                                 congruent_incorrect_rt_negative['rt'].sem()]

rt_incongruent_incorrect = pd.DataFrame()
rt_incongruent_incorrect['baseline'] = [incongruent_incorrect_rt_baseline['rt'].mean()]
rt_incongruent_incorrect['positive'] = incongruent_incorrect_rt_positive['rt'].mean()
rt_incongruent_incorrect['negative'] = incongruent_incorrect_rt_negative['rt'].mean()

rt_incongruent_incorrect = rt_incongruent_incorrect.T.rename(columns={0: 'mean rt'})

rt_incongruent_incorrect['sem'] = [incongruent_incorrect_rt_baseline['rt'].sem(),
                                 incongruent_incorrect_rt_positive['rt'].sem(),
                                 incongruent_incorrect_rt_negative['rt'].sem()]


##mgroupby experiment condition

grouped = rt_incorrect_df.groupby('negative_first')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == True:
        negative_first_incorrect_df = group
    elif name == False:
        positive_first_incorrect_df = group
        
# groupby experiment block
        
grouped = negative_first_incorrect_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_neg_set_incorrect = group
    elif name == 1:
        rt_neg_baseline_incorrect = group
    elif name == 2:
        rt_neg_positive_incorrect = group
    elif name == 3:
        rt_neg_negative_incorrect = group
        
        
baseline_mean_incorrect = rt_baseline_incorrect['rt'].mean()
positive_mean_incorrect = rt_positive_incorrect['rt'].mean()
negative_mean_incorrect = rt_negative_incorrect['rt'].mean()
        
negative_first_incorrect = pd.DataFrame()

negative_first_incorrect['baseline'] = [rt_neg_baseline_incorrect['rt'].mean()]
negative_first_incorrect['positive'] = rt_neg_positive_incorrect['rt'].mean()
negative_first_incorrect['negative'] = rt_neg_negative_incorrect['rt'].mean()

negative_first_incorrect = negative_first_incorrect.T.rename(columns={0: 'mean rt'})


negative_first_incorrect['sem'] = [rt_neg_baseline_incorrect['rt'].sem(), 
                                   rt_neg_positive_incorrect['rt'].sem(),
                                   rt_neg_negative_incorrect['rt'].sem()]


grouped = positive_first_incorrect_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_pos_set_incorrect = group
    elif name == 1:
        rt_pos_baseline_incorrect = group
    elif name == 2:
        rt_pos_positive_incorrect = group
    elif name == 3:
        rt_pos_negative_incorrect = group
        
positive_first_incorrect = pd.DataFrame()

positive_first_incorrect['baseline'] = [rt_pos_baseline_incorrect['rt'].mean()]
positive_first_incorrect['positive'] = rt_pos_positive_incorrect['rt'].mean()
positive_first_incorrect['negative'] = rt_pos_negative_incorrect['rt'].mean()

positive_first_incorrect = positive_first_incorrect.T.rename(columns={0: 'mean rt'})


positive_first_incorrect['sem'] = [rt_pos_baseline_incorrect['rt'].sem(), 
                                   rt_neg_positive_incorrect['rt'].sem(),
                                   rt_pos_negative_incorrect['rt'].sem()]


## split by congruent vs incongruent
grouped = positive_first_incorrect_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        positive_first_rt_incongruent_incorrect_df = group
    elif name == 'incongruent':
        positive_first_rt_congruent_incorrect_df = group
        
grouped = negative_first_incorrect_df.groupby('target')

# iterate over split dataframes

for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        negative_first_rt_incongruent_incorrect_df = group
    elif name == 'incongruent':
        negative_first_rt_congruent_incorrect_df = group

grouped = negative_first_rt_incongruent_incorrect_df.groupby('condition')

negative_first_incongruent_incorrect_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_incorrect_set = group
    else:
        negative_first_incongruent_incorrect_no_trainig = negative_first_incongruent_incorrect_no_trainig.append(group)



grouped = negative_first_incongruent_incorrect_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_incorrect_training_set = group
    elif name == 1:
        negative_first_incongruent_incorrect_rt_baseline = group
    elif name == 2:
        negative_first_incongruent_incorrect_rt_positive = group
    elif name == 3:
        negative_first_incongruent_incorrect_rt_negative = group
        
        
negative_first_df_rt_incongruent_incorrect = pd.DataFrame()
negative_first_df_rt_incongruent_incorrect['baseline'] = [negative_first_incongruent_incorrect_rt_baseline['rt'].mean()]
negative_first_df_rt_incongruent_incorrect['positive'] = negative_first_incongruent_incorrect_rt_positive['rt'].mean()
negative_first_df_rt_incongruent_incorrect['negative'] = negative_first_incongruent_incorrect_rt_negative['rt'].mean()
rt_congruent


negative_first_df_rt_incongruent_incorrect = negative_first_df_rt_incongruent_incorrect.T.rename(columns={0: 'mean rt'})

negative_first_df_rt_incongruent_incorrect['sem'] = [negative_first_incongruent_incorrect_rt_baseline['rt'].sem(),
                                           negative_first_incongruent_incorrect_rt_positive['rt'].sem(),
                                           negative_first_incongruent_incorrect_rt_negative['rt'].sem()]


## Congruent

        
grouped = negative_first_rt_congruent_incorrect_df.groupby('condition')

negative_first_congruent_incorrect_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_incorrect_training_set = group
    else:
        negative_first_congruent_incorrect_no_trainig = negative_first_congruent_incorrect_no_trainig.append(group)



grouped = negative_first_congruent_incorrect_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_incorrect_training_set = group
    elif name == 1:
        negative_first_df_congruent_incorrect_rt_baseline = group
    elif name == 2:
        negative_first_df_congruent_incorrect_rt_positive = group
    elif name == 3:
        negative_first_df_congruent_incorrect_rt_negative = group
        
negative_first_df_rt_congruent_incorrect = pd.DataFrame()
negative_first_df_rt_congruent_incorrect['baseline'] = [negative_first_df_congruent_incorrect_rt_baseline['rt'].mean()]
negative_first_df_rt_congruent_incorrect['positive'] = negative_first_df_congruent_incorrect_rt_positive['rt'].mean()
negative_first_df_rt_congruent_incorrect['negative'] = negative_first_df_congruent_incorrect_rt_negative['rt'].mean()
rt_congruent


negative_first_df_rt_congruent_incorrect = negative_first_df_rt_congruent_incorrect.T.rename(columns={0: 'mean rt'})

negative_first_df_rt_congruent_incorrect['sem'] = [negative_first_df_congruent_incorrect_rt_baseline['rt'].sem(),
                                         negative_first_df_congruent_incorrect_rt_positive['rt'].sem(),
                                         negative_first_df_congruent_incorrect_rt_negative['rt'].sem()]



grouped = positive_first_rt_incongruent_incorrect_df.groupby('condition')
positive_first_incongruent_incorrect_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_incorrect_training_set = group
    else:
        positive_first_incongruent_incorrect_no_trainig = positive_first_incongruent_incorrect_no_trainig.append(group)



grouped = positive_first_incongruent_incorrect_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_incorrect_training_set = group
    elif name == 1:
        positive_first_incongruent_incorrect_rt_baseline = group
    elif name == 2:
        positive_first_incongruent_incorrect_rt_positive = group
    elif name == 3:
        positive_first_incongruent_incorrect_rt_negative = group
        
        
positive_first_df_rt_incongruent_incorrect = pd.DataFrame()
positive_first_df_rt_incongruent_incorrect['baseline'] = [positive_first_incongruent_incorrect_rt_baseline['rt'].mean()]
positive_first_df_rt_incongruent_incorrect['positive'] = positive_first_incongruent_incorrect_rt_positive['rt'].mean()
positive_first_df_rt_incongruent_incorrect['negative'] = positive_first_incongruent_incorrect_rt_negative['rt'].mean()
rt_congruent


positive_first_df_rt_incongruent_incorrect = positive_first_df_rt_incongruent_incorrect.T.rename(columns={0: 'mean rt'})

positive_first_df_rt_incongruent_incorrect['sem'] = [positive_first_incongruent_incorrect_rt_baseline['rt'].sem(),
                                           positive_first_incongruent_incorrect_rt_positive['rt'].sem(),
                                           positive_first_incongruent_incorrect_rt_negative['rt'].sem()]


## Incongruent

        
grouped = positive_first_rt_congruent_incorrect_df.groupby('condition')

positive_first_congruent_incorrect_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_incorrect_training_set = group
    else:
        positive_first_congruent_incorrect_no_trainig = positive_first_congruent_incorrect_no_trainig.append(group)



grouped = positive_first_congruent_incorrect_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_incorrect_training_set = group
    elif name == 1:
        positive_first_df_congruent_incorrect_rt_baseline = group
    elif name == 2:
        positive_first_df_congruent_incorrect_rt_positive = group
    elif name == 3:
        positive_first_df_congruent_incorrect_rt_negative = group
        
positive_first_df_rt_congruent_incorrect = pd.DataFrame()
positive_first_df_rt_congruent_incorrect['baseline'] = [positive_first_df_congruent_incorrect_rt_baseline['rt'].mean()]
positive_first_df_rt_congruent_incorrect['positive'] = positive_first_df_congruent_incorrect_rt_positive['rt'].mean()
positive_first_df_rt_congruent_incorrect['negative'] = positive_first_df_congruent_incorrect_rt_negative['rt'].mean()

positive_first_df_rt_congruent_incorrect = positive_first_df_rt_congruent_incorrect.T.rename(columns={0: 'mean rt'})

positive_first_df_rt_congruent_incorrect['sem'] = [positive_first_df_congruent_incorrect_rt_baseline['rt'].sem(),
                                                 positive_first_df_congruent_incorrect_rt_positive['rt'].sem(),
                                                 positive_first_df_congruent_incorrect_rt_negative['rt'].sem()]

# %%
list_rt_df = [positive_first_df_rt_incongruent_incorrect, positive_first_df_rt_congruent_incorrect,
              negative_first_df_rt_incongruent_incorrect, negative_first_df_rt_congruent_incorrect]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    #print(idx)
    #print(df['mean rt'].to_numpy()[0])
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'positive_first_df_rt_incongruent_incorrect'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='positive_first_df_rt_incongruent_incorrect')
        x_arr = x_arr -.1
    elif idx == 1:
        cond_temp = 'positive_first_df_rt_congruent'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='positive_first_df_rt_congruent_incorrect')
        x_arr = x_arr
    elif idx == 2:
        cond_temp = 'negative_first_df_rt_incongruent'
        color_temp = 'maroon'
        leg_temp = mpatches.Patch(color=color_temp, label='negative_first_df_rt_incongruent_incorrect')
        x_arr = x_arr +.1
    elif idx == 3:
        cond_temp = 'negative_first_df_rt_incongruent'
        color_temp = 'midnightblue'
        leg_temp = mpatches.Patch(color=color_temp, label='negative_first_df_rt_congruent_incorrect')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    

fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('incorrect trials: positive vs negative first & congruent vs incongruent')

plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
list_rt_df = [negative_first_df_rt_incongruent_incorrect, negative_first_df_rt_congruent_incorrect]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):

    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'negative_first_df_rt_incongruent_incorrect'
        color_temp = 'maroon'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent negative first_incorrect')
        x_arr = x_arr
    elif idx == 1:
        cond_temp = 'negative_first_df_rt_incongruent_incorrect'
        color_temp = 'midnightblue'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent negative first_incorrect')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    
fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('incorrect trials: negative first & congruent vs congruent')


plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
list_rt_df = [positive_first_df_rt_incongruent_incorrect, positive_first_df_rt_congruent_incorrect]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'positive_first_df_rt_incongruent_incorrect'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='incongruent positive first_incorrect')
        x_arr = x_arr
    elif idx == 1:
        cond_temp = 'positive_first_df_rt_congruent_correct'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='congruent positive first_incorrect')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[2]-0.01, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    
fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[3] = 'Negative'
labels[2] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('incorrect trials: positive first & congruent vs congruent')

plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)


plt.show()

# %% [markdown]
# ## Extra Plots

# %%
list_rt_df = [rt_incorrect, rt_correct]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    #print(idx)
    #print(df['mean rt'].to_numpy()[0])
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'rt_incorrect'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='rt_incorrect')
        x_arr = x_arr -.1
    elif idx == 1:
        cond_temp = 'rt_correct'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='rt_correct')
        x_arr = x_arr
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    

fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('incorrect vs correct trials')

plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
list_rt_df = [rt_incongruent_incorrect, rt_congruent_incorrect,
             rt_incongruent_correct, rt_congruent_correct]

legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    #print(idx)
    #print(df['mean rt'].to_numpy()[0])
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'rt_incongruent_incorrect_df'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='rt_incongruent_incorrect_df')
        x_arr = x_arr -.1
    elif idx == 1:
        cond_temp = 'rt_congruent_incorrect_df'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='rt_congruent_incorrect_df')
        x_arr = x_arr
    elif idx == 2:
        cond_temp = 'rt_incongruent_correct_df'
        color_temp = 'maroon'
        leg_temp = mpatches.Patch(color=color_temp, label='rt_incongruent_correct_df')
        x_arr = x_arr +.1
    elif idx == 3:
        cond_temp = 'rt_congruent_correct_df'
        color_temp = 'midnightblue'
        leg_temp = mpatches.Patch(color=color_temp, label='rt_congruent_correct_df')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    

fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('incorrect vs correct & congruent vs congruent')

plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=4, fancybox=True, shadow=True)

plt.show()

# %%
list_rt_df = [negative_first, positive_first,
             negative_first_correct, positive_first_correct,
             negative_first_incorrect, positive_first_incorrect]


legend_list = []

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


for idx, df in enumerate(list_rt_df):
    #print(idx)
    #print(df['mean rt'].to_numpy()[0])
    x_arr = np.array([0, 1, 2])

    if idx == 0:
        cond_temp = 'negative_first'
        color_temp = 'r'
        leg_temp = mpatches.Patch(color=color_temp, label='negative_first')
        x_arr = x_arr -.1
    elif idx == 1:
        cond_temp = 'positive_first'
        color_temp = 'maroon'
        leg_temp = mpatches.Patch(color=color_temp, label='positive_first')
        x_arr = x_arr
    elif idx == 2:
        cond_temp = 'negative_first_correct'
        color_temp = 'cornflowerblue'
        leg_temp = mpatches.Patch(color=color_temp, label='negative_first_correct')
        x_arr = x_arr +.1
    elif idx == 3:
        cond_temp = 'positive_first_correct'
        color_temp = 'midnightblue'
        leg_temp = mpatches.Patch(color=color_temp, label='positive_first_correct')
        x_arr = x_arr +.2
    elif idx == 4:
        cond_temp = 'negative_first_incorrect'
        color_temp = 'lime'
        leg_temp = mpatches.Patch(color=color_temp, label='negative_first_incorrect')
        x_arr = x_arr +.1
    elif idx == 5:
        cond_temp = 'positive_first_incorrect'
        color_temp = 'darkgreen'
        leg_temp = mpatches.Patch(color=color_temp, label='positive_first_incorrect')
        x_arr = x_arr +.2
        
    ax.plot(x_arr, df['mean rt'].to_numpy(), color=color_temp, marker='.')

    # draw custom error bars
    plt.plot([x_arr[0], x_arr[0]],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[1], x_arr[1]],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
              (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[2], x_arr[2]],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
              (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0]),
              (df['mean rt'].to_numpy()[0] + df['sem'].to_numpy()[0])],
             color=color_temp,
              lw=0.5)

    plt.plot([x_arr[0]-0.02, x_arr[0]+.02],
             [(df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0]),
             (df['mean rt'].to_numpy()[0] - df['sem'].to_numpy()[0])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.02, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] + df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)


    plt.plot([x_arr[1]-0.01, x_arr[1]+.02],
             [(df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1]),
             (df['mean rt'].to_numpy()[1] - df['sem'].to_numpy()[1])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] + df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)

    plt.plot([x_arr[2]-0.02, x_arr[2]+.02],
             [(df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2]),
             (df['mean rt'].to_numpy()[2] - df['sem'].to_numpy()[2])],
             color=color_temp,
             lw=0.5)
    
    legend_list.append(leg_temp)
    

fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.1, 0.5)

plt.title('positive vs negative first & correct vs incorrect')

plt.legend(handles=legend_list, loc='lower center', bbox_to_anchor=(0.5, -0.15),
          ncol=3, fancybox=True, shadow=True)

plt.show()

# %% [markdown]
# # Generate DataFrame with all rt data splits

# %%
rts_df
rt_incorrect
rt_correct

rt_incongruent
rt_congruent
negative_first
positive_first
negative_first_df_rt_incongruent
negative_first_df_rt_congruent
positive_first_df_rt_incongruent
positive_first_df_rt_congruent

# correct df
rt_incongruent_correct
rt_congruent_correct
negative_first_correct
positive_first_correct
negative_first_df_rt_incongruent_correct
negative_first_df_rt_congruent_correct
positive_first_df_rt_incongruent_correct
positive_first_df_rt_congruent_correct


# incorrect df
rt_incongruent_incorrect
rt_congruent_incorrect
negative_first_incorrect
positive_first_incorrect
negative_first_df_rt_incongruent_incorrect
negative_first_df_rt_congruent_incorrect
positive_first_df_rt_incongruent_incorrect
positive_first_df_rt_congruent_incorrect
# Out:
#            mean rt       sem
# baseline  0.254138  0.003325
# positive  0.249194  0.002665
# negative  0.254730  0.003433

# %%
# condition
negative_first = negative_first.T
positive_first = positive_first.T

# correct vs incorrect
rt_incorrect = rt_incorrect.T
rt_correct = rt_correct.T

# condition + correct vs incorrect
negative_first_correct = negative_first_correct.T
positive_first_correct = positive_first_correct.T

negative_first_incorrect = negative_first_incorrect.T
positive_first_incorrect = positive_first_incorrect.T

# condition + congruent vs incongruent
positive_first_df_rt_congruent = positive_first_df_rt_congruent.T
positive_first_df_rt_incongruent = positive_first_df_rt_incongruent.T

negative_first_df_rt_congruent = negative_first_df_rt_congruent.T
negative_first_df_rt_incongruent = negative_first_df_rt_incongruent.T

# incorrect vs correct - incongruent vs congruent
rt_incongruent_correct = rt_incongruent_correct.T
rt_congruent_correct = rt_congruent_correct.T

rt_incongruent_incorrect = rt_incongruent_incorrect.T
rt_congruent_incorrect = rt_congruent_incorrect.T

# condition / correct vs incorrect / congruent vs incongruent
negative_first_df_rt_incongruent_correct = negative_first_df_rt_incongruent_correct.T
negative_first_df_rt_congruent_correct = negative_first_df_rt_congruent_correct.T
positive_first_df_rt_incongruent_correct = positive_first_df_rt_incongruent_correct.T
positive_first_df_rt_congruent_correct = positive_first_df_rt_congruent_correct.T


negative_first_df_rt_incongruent_incorrect = negative_first_df_rt_incongruent_incorrect.T
negative_first_df_rt_congruent_incorrect = negative_first_df_rt_congruent_incorrect.T
positive_first_df_rt_incongruent_incorrect = positive_first_df_rt_incongruent_incorrect.T
positive_first_df_rt_congruent_incorrect = positive_first_df_rt_congruent_incorrect.T

# %%
negative_first
# Out:
#          baseline  positive  negative
# mean rt  0.358946  0.352785  0.354249
# sem      0.001189  0.001156  0.001145

# %%
# condition
negative_first = negative_first.rename(columns={'baseline':'baseline_negative_first',
                                               'positive':'2.Block_positive_negative_first',
                                               'negative':'1.Block_negative_negative_first'})
positive_first = positive_first.rename(columns={'baseline':'baseline_positive_first',
                                               'positive':'1.Block_positive_positive_first',
                                               'negative':'2.Block_negative_positive_first'})

# correct vs incorrect
rt_incorrect = rt_incorrect.rename(columns={'baseline':'baseline_incorrect',
                                               'positive':'positive_incorrect',
                                               'negative':'negative_incorrect'})
rt_correct = rt_correct.rename(columns={'baseline':'baseline_correct',
                                               'positive':'positive_correct',
                                               'negative':'negative_correct'})

# condition + correct vs incorrect
negative_first_correct = negative_first_correct.rename(columns={'baseline':'baseline_negative_first_correct',
                                               'positive':'2.Block_positive_negative_first_correct',
                                               'negative':'1.Block_negative_negative_first_correct'})
positive_first_correct = positive_first_correct.rename(columns={'baseline':'baseline_positive_first_correct',
                                               'positive':'1.Block_positive_positive_first_correct',
                                               'negative':'2.Block_negative_positive_first_correct'})

negative_first_incorrect = negative_first_incorrect.rename(columns={'baseline':'baseline_negative_first_incorrect',
                                               'positive':'2.Block_positive_negative_first_incorrect',
                                               'negative':'1.Block_negative_negative_first_incorrect'})
positive_first_incorrect = positive_first_incorrect.rename(columns={'baseline':'baseline_positive_first_incorrect',
                                               'positive':'1.Block_positive_positive_first_incorrect',
                                               'negative':'2.Block_negative_positive_first_incorrect'})

# condition + congruent vs incongruent
positive_first_df_rt_congruent = positive_first_df_rt_congruent.rename(columns={'baseline':'baseline_positive_first_congruent',
                                               'positive':'1.Block_positive_positive_first_congruent',
                                               'negative':'2.Block_negative_positive_first_congruent'})

positive_first_df_rt_incongruent = positive_first_df_rt_incongruent.rename(columns={'baseline':'baseline_positive_first_incongruent',
                                               'positive':'1.Block_positive_positive_first_incongruent',
                                               'negative':'2.Block_negative_positive_first_incongruent'})

negative_first_df_rt_congruent = positive_first_df_rt_congruent.rename(columns={'baseline':'baseline_negative_first_congruent',
                                               'positive':'2.Block_positive_negative_first_congruent',
                                               'negative':'1.Block_negative_positive_first_congruent'})

negative_first_df_rt_incongruent = positive_first_df_rt_incongruent.rename(columns={'baseline':'baseline_negative_first_incongruent',
                                               'positive':'2.Block_positive_negative_first_incongruent',
                                               'negative':'1.Block_negative_negative_first_incongruent'})

# incorrect vs correct - incongruent vs congruent
rt_incongruent_correct = rt_incongruent_correct.rename(columns={'baseline':'baseline_incongruent_correct',
                                               'positive':'positive_incongruent_correct',
                                               'negative':'negative_incongruent_correct'})
rt_congruent_correct = rt_congruent_correct.rename(columns={'baseline':'baseline_congruent_correct',
                                               'positive':'positive_congruent_correct',
                                               'negative':'negative_congruent_correct'})

rt_incongruent_incorrect = rt_incongruent_incorrect.rename(columns={'baseline':'baseline_incongruent_incorrect',
                                               'positive':'positive_incongruent_incorrect',
                                               'negative':'negative_incongruent_incorrect'})
rt_congruent_incorrect = rt_congruent_incorrect.rename(columns={'baseline':'baseline_congruent_incorrect',
                                               'positive':'positive_congruent_incorrect',
                                               'negative':'negative_congruent_incorrect'})

# condition / correct vs incorrect / congruent vs incongruent
negative_first_df_rt_incongruent_correct = negative_first_df_rt_incongruent_correct.rename(
                                                        columns={'baseline':'baseline_negative_first_incongruent_correct',
                                                                 'positive':'2.Block_positive_negative_first_incongruent_correct',
                                                                 'negative':'1.Block_negative_negative_first_incongruent_correct'})
negative_first_df_rt_congruent_correct = negative_first_df_rt_congruent_correct.rename(
                                                        columns={'baseline':'baseline_negative_first_congruent_correct',
                                                                 'positive':'2.Block_positive_negative_first_congruent_correct',
                                                                 'negative':'1.Block_negative_negative_first_congruent_correct'})
positive_first_df_rt_incongruent_correct = positive_first_df_rt_incongruent_correct.rename(
                                                        columns={'baseline':'baseline_positive_first_incongruent_correct',
                                                                 'positive':'1.Block_positive_positive_first_incongruent_correct',
                                                                 'negative':'2.Block_negative_positive_first_incongruent_correct'})
positive_first_df_rt_congruent_correct = positive_first_df_rt_congruent_correct.rename(
                                                        columns={'baseline':'baseline_positive_first_congruent_correct',
                                                                 'positive':'1.Block_positive_positive_first_congruent_correct',
                                                                 'negative':'2.Block_negative_positive_first_congruent_correct'})


negative_first_df_rt_incongruent_incorrect = negative_first_df_rt_incongruent_incorrect.rename(
                                                        columns={'baseline':'baseline_positive_first_incongruent_incorrect',
                                                                 'positive':'1.Block_positive_positive_first_incongruent_incorrect',
                                                                 'negative':'2.Block_negative_positive_first_incongruent_incorrect'})
negative_first_df_rt_congruent_incorrect = negative_first_df_rt_congruent_incorrect.rename(
                                                        columns={'baseline':'baseline_negative_first_congruent_incorrect',
                                                                 'positive':'2.Block_positive_negative_first_congruent_incorrect',
                                                                 'negative':'1.Block_negative_negative_first_congruent_incorrect'})
positive_first_df_rt_incongruent_incorrect = positive_first_df_rt_incongruent_incorrect.rename(
                                                        columns={'baseline':'baseline_negative_first_congruent_incorrect',
                                                                 'positive':'2.Block_positive_negative_first_congruent_incorrect',
                                                                 'negative':'1.Block_negative_negative_first_congruent_incorrect'})
positive_first_df_rt_congruent_incorrect = positive_first_df_rt_congruent_incorrect.rename(
                                                        columns={'baseline':'baseline_positive_first_congruent_incorrect',
                                                                 'positive':'1.Block_positive_positive_first_congruent_incorrect',
                                                                 'negative':'2.Block_negative_positive_first_congruent_incorrect'})

# %%
negative_first
# Out:
#          baseline_negative_first  2.Block_positive_negative_first  \
# mean rt                 0.358946                         0.352785
# sem                     0.001189                         0.001156
#
#          1.Block_negative_negative_first
# mean rt                         0.354249
# sem                             0.001145

# %%
negative_first_df_rt_incongruent
# Out:
#          baseline_positive_first_incongruent  \
# mean rt                             0.320401
# sem                                 0.001544
#
#          1.Block_positive_positive_first_incongruent  \
# mean rt                                     0.310283
# sem                                         0.001434
#
#          2.Block_negative_positive_first_incongruent
# mean rt                                     0.314328
# sem                                         0.001477

# %%
negative_first
positive_first
# correct vs incorrect
rt_incorrect
rt_correct
# condition + correct vs incorrect
negative_first_correct
positive_first_correct
negative_first_incorrect
positive_first_incorrect
# condition + congruent vs incongruent
positive_first_df_rt_congruent
positive_first_df_rt_incongruent
negative_first_df_rt_congruent
negative_first_df_rt_incongruent

# incorrect vs correct - incongruent vs congruent
rt_incongruent_correct
rt_congruent_correct
rt_incongruent_incorrect
rt_congruent_incorrect

# condition / correct vs incorrect / congruent vs incongruent
negative_first_df_rt_incongruent_correct
negative_first_df_rt_congruent_correct
positive_first_df_rt_incongruent_correct
positive_first_df_rt_congruent_correct
negative_first_df_rt_incongruent_incorrect
negative_first_df_rt_congruent_incorrect
positive_first_df_rt_incongruent_incorrect
positive_first_df_rt_congruent_incorrect
# Out:
#          baseline_positive_first_congruent_incorrect  \
# mean rt                                     0.254138
# sem                                         0.003325
#
#          1.Block_positive_positive_first_congruent_incorrect  \
# mean rt                                           0.249194
# sem                                               0.002665
#
#          2.Block_negative_positive_first_congruent_incorrect
# mean rt                                           0.254730
# sem                                               0.003433

# %%
rt_means = pd.concat([positive_first_df_rt_congruent.T, positive_first_df_rt_incongruent.T,
                      negative_first_df_rt_congruent.T, negative_first_df_rt_incongruent.T])

# %%
rt_means = pd.concat([negative_first.T, positive_first.T,
                      rt_incorrect.T, rt_correct.T,
                      negative_first_correct.T, positive_first_correct.T,
                      negative_first_incorrect.T, positive_first_incorrect.T,
                      positive_first_df_rt_congruent.T, positive_first_df_rt_incongruent.T,
                      negative_first_df_rt_congruent.T, negative_first_df_rt_incongruent.T,
                      rt_incongruent_correct.T, rt_congruent_correct.T,
                      rt_incongruent_incorrect.T, rt_congruent_incorrect.T,
                      negative_first_df_rt_incongruent_correct.T, negative_first_df_rt_congruent_correct.T,
                      positive_first_df_rt_incongruent_correct.T, positive_first_df_rt_congruent_correct.T,
                      negative_first_df_rt_incongruent_incorrect.T, negative_first_df_rt_congruent_incorrect.T,
                      positive_first_df_rt_incongruent_incorrect.T, positive_first_df_rt_congruent_incorrect.T])

# %%
rt_means
# Out:
#                                                      mean rt       sem
# baseline_negative_first                             0.358946  0.001189
# 2.Block_positive_negative_first                     0.352785  0.001156
# 1.Block_negative_negative_first                     0.354249  0.001145
# baseline_positive_first                             0.347851  0.001167
# 1.Block_positive_positive_first                     0.332122  0.000996
# ...                                                      ...       ...
# 2.Block_positive_negative_first_congruent_incor...  0.344147  0.012685
# 1.Block_negative_negative_first_congruent_incor...  0.342826  0.012039
# baseline_positive_first_congruent_incorrect         0.254138  0.003325
# 1.Block_positive_positive_first_congruent_incor...  0.249194  0.002665
# 2.Block_negative_positive_first_congruent_incor...  0.254730  0.003433
#
# [72 rows x 2 columns]

# %%
rt_means.to_csv('/home/michael/git/master_thesis/data/reaction_times_means_+_sem.tsv', sep='\t')
