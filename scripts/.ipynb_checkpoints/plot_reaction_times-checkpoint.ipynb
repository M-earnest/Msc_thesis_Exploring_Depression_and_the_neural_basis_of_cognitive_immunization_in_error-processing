# %% [markdown]
# ToDo
# - clean-up

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import matplotlib.patches as mpatches
import numpy as np
import os
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score #model evaluation

# %%
rootdir = '/home/michael/data/derivatives/results/dataframes'

# %%
rt_df = pd.DataFrame()

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        #print(file)
        #print os.path.join(subdir, file)
        filepath = subdir + os.sep + file
        if filepath.endswith(".tsv"):
            print (filepath)
            if filepath == '/home/michael/data/derivatives/results/dataframes/debugging_rt_data_sub_x.tsv':
                print('no, no')
            else:
                df_temp = pd.read_csv(filepath, sep='\t',  index_col=0) 
                rt_df = rt_df.append(df_temp)
                display(df_temp)
                
rt_df.sort_values(by=('subject'))
# Out:
# /home/michael/data/derivatives/results/dataframes/rt_data_sub-007.tsv
#       trial  condition   reaction        rt       target flanker  block  \
# 0         0          0    correct  1.203125  incongruent    left      0
# 1         1          0    correct  0.427734  incongruent   right      0
# 2         2          0    correct  0.420898  incongruent    left      0
# 3         3          0    correct  0.413086    congruent    left      0
# 4         4          0    correct  0.405273  incongruent    left      0
# ...     ...        ...        ...       ...          ...     ...    ...
# 1243   1243          2    correct  0.505859  incongruent    left      2
# 1244   1244          2    correct  0.482422    congruent   right      2
# 1245   1245          2  incorrect  0.442383  incongruent   right      2
# 1246   1246          2    correct  0.946289  incongruent    left      2
# 1247   1247          2    correct  0.523438    congruent   right      2
#
#       subject  negative_first
# ...

# %%
rt_df.to_csv('/home/michael/Desktop/reaction_times.tsv', sep='\t', index=False)

# %%
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#    display(rt_df)

# %%
grouped = rt_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        training_set = group
    elif name == 1:
        rt_baseline = group
    elif name == 2:
        rt_positive = group
    elif name == 3:
        rt_negative = group

# %%
rt_baseline.sort_values('subject')
# Out:
#      trial  condition reaction        rt       target flanker  block  subject  \
# 447    447          1  correct  0.291016    congruent   right      1        2
# 319    319          1  correct  0.373047  incongruent   right      1        2
# 318    318          1  correct  0.250000    congruent    left      1        2
# 317    317          1  correct  0.429688  incongruent   right      1        2
# 316    316          1  correct  0.226562    congruent    left      1        2
# ..     ...        ...      ...       ...          ...     ...    ...      ...
# 178    178          1  correct  0.526367  incongruent   right      1       38
# 177    177          1  correct  0.581055    congruent    left      1       38
# 176    176          1  correct  0.476562    congruent   right      1       38
# 186    186          1  correct  0.259766    congruent   right      1       38
# 248    248          1  correct  0.281250    congruent   right      1       38
#
#      negative_first
# ...

# %%
baseline_mean = rt_baseline['rt'].mean()
positive_mean = rt_positive['rt'].mean()
negative_mean = rt_negative['rt'].mean()

# %%
grouped = rt_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        rt_incongruent_df = group
    elif name == 'incongruent':
        rt_congruent_df = group

# %%
grouped = rt_incongruent_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_training_set = group
    elif name == 1:
        incongruent_rt_baseline = group
    elif name == 2:
        incongruent_rt_positive = group
    elif name == 3:
        incongruent_rt_negative = group

# %%
grouped = rt_incongruent_df.groupby('condition')

incongruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_training_set = group
    else:
        incongruent_no_trainig = incongruent_no_trainig.append(group)

# %%
grouped = rt_congruent_df.groupby('condition')

congruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        congruent_no_trainig = congruent_no_trainig.append(group)

# %%
cong_vs_incong = pd.DataFrame()
cong_vs_incong['congruent_rt'] = [congruent_no_trainig['rt'].mean()]
cong_vs_incong['incongruent_rt'] = incongruent_no_trainig['rt'].mean()

# %%
grouped = rt_congruent_df.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    elif name == 1:
        congruent_rt_baseline = group
    elif name == 2:
        congruent_rt_positive = group
    elif name == 3:
        congruent_rt_negative = group

# %%
rt_congruent = pd.DataFrame()
rt_congruent['baseline'] = [congruent_rt_baseline['rt'].mean()]
rt_congruent['positive'] = congruent_rt_positive['rt'].mean()
rt_congruent['negative'] = congruent_rt_negative['rt'].mean()
rt_congruent


rt_congruent = rt_congruent.T.rename(columns={0: 'mean rt'})

rt_congruent['std'] = [congruent_rt_baseline['rt'].std(), congruent_rt_positive['rt'].std(),
                       congruent_rt_negative['rt'].std()]

# %%
rt_incongruent = pd.DataFrame()
rt_incongruent['baseline'] = [incongruent_rt_baseline['rt'].mean()]
rt_incongruent['positive'] = incongruent_rt_positive['rt'].mean()
rt_incongruent['negative'] = incongruent_rt_negative['rt'].mean()

rt_incongruent = rt_incongruent.Tc

rt_incongruent['std'] = [incongruent_rt_baseline['rt'].std(), incongruent_rt_positive['rt'].std(),
                         incongruent_rt_negative['rt'].std()]

# %%
sns.scatterplot(data=cong_vs_incong.T)
plt.ylim(0.3, 0.4)
plt.show()

# %%
sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)

ax.plot(rt_incongruent['mean rt'].to_numpy(), color='r')
#ax.plot(rt_incongruent['mean rt'].to_numpy()- rt_incongruent['std'].to_numpy(), color='r', alpha=0.2)
#ax.plot(rt_incongruent['mean rt'].to_numpy()+ rt_incongruent['std'].to_numpy(), color='r', alpha=0.2)

#ax.fill_between(np.arange(len(rt_incongruent['mean rt'].to_numpy())),
#                 rt_incongruent['mean rt'].to_numpy() - rt_incongruent['std'].to_numpy(),
#                 rt_incongruent['mean rt'].to_numpy() + rt_incongruent['std'].to_numpy(), color='r', alpha=0.07)

# draw custom error bars
plt.plot([0, 0], [(rt_incongruent['mean rt'].to_numpy()[0] + rt_incongruent['std'].to_numpy()[0]),
                  (rt_incongruent['mean rt'].to_numpy()[0] - rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)

plt.plot([1, 1], [(rt_incongruent['mean rt'].to_numpy()[1] + rt_incongruent['std'].to_numpy()[1]),
                  (rt_incongruent['mean rt'].to_numpy()[1] - rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)

plt.plot([2, 2], [(rt_incongruent['mean rt'].to_numpy()[2] + rt_incongruent['std'].to_numpy()[2]),
                  (rt_incongruent['mean rt'].to_numpy()[2] - rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)


plt.plot([-0.02, 0.02], [(rt_incongruent['mean rt'].to_numpy()[0] + rt_incongruent['std'].to_numpy()[0]),
                  (rt_incongruent['mean rt'].to_numpy()[0] + rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)

plt.plot([-0.02, 0.02], [(rt_incongruent['mean rt'].to_numpy()[0] - rt_incongruent['std'].to_numpy()[0]),
                  (rt_incongruent['mean rt'].to_numpy()[0] - rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)


plt.plot([0.98, 1.02], [(rt_incongruent['mean rt'].to_numpy()[1] + rt_incongruent['std'].to_numpy()[1]),
                  (rt_incongruent['mean rt'].to_numpy()[1] + rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)


plt.plot([0.98, 1.02], [(rt_incongruent['mean rt'].to_numpy()[1] - rt_incongruent['std'].to_numpy()[1]),
                  (rt_incongruent['mean rt'].to_numpy()[1] - rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)

plt.plot([1.98, 2.02], [(rt_incongruent['mean rt'].to_numpy()[2] + rt_incongruent['std'].to_numpy()[2]),
                  (rt_incongruent['mean rt'].to_numpy()[2] + rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)

plt.plot([1.98, 2.02], [(rt_incongruent['mean rt'].to_numpy()[2] - rt_incongruent['std'].to_numpy()[2]),
                  (rt_incongruent['mean rt'].to_numpy()[2] - rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)


ax.plot(rt_congruent['mean rt'].to_numpy())
#ax.plot(rt_congruent['mean rt'].to_numpy()- rt_congruent['std'].to_numpy(), color='b', alpha=0.2)
#ax.plot(rt_congruent['mean rt'].to_numpy()+ rt_congruent['std'].to_numpy(), color='b', alpha=0.2)

#ax.fill_between(np.arange(len(rt_congruent['mean rt'].to_numpy())),
#                 rt_congruent['mean rt'].to_numpy() - rt_congruent['std'].to_numpy(),
#                 rt_congruent['mean rt'].to_numpy() + rt_congruent['std'].to_numpy(), color='b', alpha=0.07)

# draw custom error bars
plt.plot([0, 0], [(rt_congruent['mean rt'].to_numpy()[0] + rt_congruent['std'].to_numpy()[0]),
                  (rt_congruent['mean rt'].to_numpy()[0] - rt_congruent['std'].to_numpy()[0])], 'b', lw=0.5)

plt.plot([1, 1], [(rt_congruent['mean rt'].to_numpy()[1] + rt_congruent['std'].to_numpy()[1]),
                  (rt_congruent['mean rt'].to_numpy()[1] - rt_congruent['std'].to_numpy()[1])], 'b', lw=0.5)

plt.plot([2, 2], [(rt_congruent['mean rt'].to_numpy()[2] + rt_congruent['std'].to_numpy()[2]),
                  (rt_congruent['mean rt'].to_numpy()[2] - rt_congruent['std'].to_numpy()[2])], 'b', lw=0.5)


plt.plot([-0.02, 0.02], [(rt_congruent['mean rt'].to_numpy()[0] + rt_congruent['std'].to_numpy()[0]),
                  (rt_congruent['mean rt'].to_numpy()[0] + rt_congruent['std'].to_numpy()[0])], 'b', lw=0.5)

plt.plot([-0.02, 0.02], [(rt_congruent['mean rt'].to_numpy()[0] - rt_congruent['std'].to_numpy()[0]),
                  (rt_congruent['mean rt'].to_numpy()[0] - rt_congruent['std'].to_numpy()[0])], 'b', lw=0.5)


plt.plot([0.98, 1.02], [(rt_congruent['mean rt'].to_numpy()[1] + rt_congruent['std'].to_numpy()[1]),
                  (rt_congruent['mean rt'].to_numpy()[1] + rt_congruent['std'].to_numpy()[1])], 'b', lw=0.5)


plt.plot([0.98, 1.02], [(rt_congruent['mean rt'].to_numpy()[1] - rt_congruent['std'].to_numpy()[1]),
                  (rt_congruent['mean rt'].to_numpy()[1] - rt_congruent['std'].to_numpy()[1])], 'b', lw=0.5)

plt.plot([1.98, 2.02], [(rt_congruent['mean rt'].to_numpy()[2] + rt_congruent['std'].to_numpy()[2]),
                  (rt_congruent['mean rt'].to_numpy()[2] + rt_congruent['std'].to_numpy()[2])], 'b', lw=0.5)

plt.plot([1.98, 2.02], [(rt_congruent['mean rt'].to_numpy()[2] - rt_congruent['std'].to_numpy()[2]),
                  (rt_congruent['mean rt'].to_numpy()[2] - rt_congruent['std'].to_numpy()[2])], 'b', lw=0.5)


fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.2, 0.5)

incongruent_leg = mpatches.Patch(color='r', label='incongruent')
congruent_leg = mpatches.Patch(color='b', label='congruent')

plt.legend(handles=[incongruent_leg, congruent_leg])

plt.show()

# %%
grouped = rt_df.groupby('negative_first')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == True:
        negative_first_df = group
    elif name == False:
        positive_first_df = group

# %%
sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)

ax.plot([positive_first_df['rt'].mean(), negative_first_df['rt'].mean()], color='r')



fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[2] = 'Negative first'
labels[1] = 'Positive first'

ax.set_xticklabels(labels)
ax.set_xticklabels(labels)

# draw custom error bars
plt.plot([0, 0], [(positive_first_df['rt'].mean() + positive_first_df['rt'].std()),
                  (positive_first_df['rt'].mean() - positive_first_df['rt'].std())], 'r', lw=0.5)

plt.plot([-0.02, 0.02], [(positive_first_df['rt'].mean() + positive_first_df['rt'].std()),
                  (positive_first_df['rt'].mean() + positive_first_df['rt'].std())], 'r', lw=0.5)

plt.plot([-0.02, 0.02], [(positive_first_df['rt'].mean() - positive_first_df['rt'].std()),
                  (positive_first_df['rt'].mean() - positive_first_df['rt'].std())], 'r', lw=0.5)


plt.plot([1, 1], [(negative_first_df['rt'].mean() + negative_first_df['rt'].std()),
                  (negative_first_df['rt'].mean() - negative_first_df['rt'].std())], 'r', lw=0.5)

plt.plot([0.98, 1.02], [(negative_first_df['rt'].mean() - negative_first_df['rt'].std()),
                  (negative_first_df['rt'].mean() - negative_first_df['rt'].std())], 'r', lw=0.5)

plt.plot([0.98, 1.02], [(negative_first_df['rt'].mean() + negative_first_df['rt'].std()),
                  (negative_first_df['rt'].mean() + negative_first_df['rt'].std())], 'r', lw=0.5)



plt.ylim(0.2, 0.5)


plt.show()

# %%
grouped = positive_first_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        positive_first_rt_incongruent_df = group
    elif name == 'incongruent':
        positive_first_rt_congruent_df = group
        
grouped = negative_first_df.groupby('target')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 'congruent':
        negative_first_rt_incongruent_df = group
    elif name == 'incongruent':
        negative_first_rt_congruent_df = group

# %%
grouped = negative_first_rt_incongruent_df.groupby('condition')

negative_first_incongruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        negative_first_incongruent_no_trainig = negative_first_incongruent_no_trainig.append(group)



grouped = negative_first_incongruent_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_training_set = group
    elif name == 1:
        negative_first_incongruent_rt_baseline = group
    elif name == 2:
        negative_first_incongruent_rt_positive = group
    elif name == 3:
        negative_first_incongruent_rt_negative = group
        
        
negative_first_df_rt_incongruent = pd.DataFrame()
negative_first_df_rt_incongruent['baseline'] = [negative_first_incongruent_rt_baseline['rt'].mean()]
negative_first_df_rt_incongruent['positive'] = negative_first_incongruent_rt_positive['rt'].mean()
negative_first_df_rt_incongruent['negative'] = negative_first_incongruent_rt_negative['rt'].mean()
rt_congruent


negative_first_df_rt_incongruent = negative_first_df_rt_incongruent.T.rename(columns={0: 'mean rt'})

negative_first_df_rt_incongruent['std'] = [negative_first_incongruent_rt_baseline['rt'].std(),
                                           negative_first_incongruent_rt_positive['rt'].std(),
                                           negative_first_incongruent_rt_negative['rt'].std()]


## Congruent

        
grouped = negative_first_rt_congruent_df.groupby('condition')

negative_first_congruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        negative_first_congruent_no_trainig = negative_first_congruent_no_trainig.append(group)



grouped = negative_first_congruent_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    elif name == 1:
        negative_first_df_congruent_rt_baseline = group
    elif name == 2:
        negative_first_df_congruent_rt_positive = group
    elif name == 3:
        negative_first_df_congruent_rt_negative = group
        
negative_first_df_rt_congruent = pd.DataFrame()
negative_first_df_rt_congruent['baseline'] = [negative_first_df_congruent_rt_baseline['rt'].mean()]
negative_first_df_rt_congruent['positive'] = negative_first_df_congruent_rt_positive['rt'].mean()
negative_first_df_rt_congruent['negative'] = negative_first_df_congruent_rt_negative['rt'].mean()
rt_congruent


negative_first_df_rt_congruent = negative_first_df_rt_congruent.T.rename(columns={0: 'mean rt'})

negative_first_df_rt_congruent['std'] = [negative_first_df_congruent_rt_baseline['rt'].std(),
                                         negative_first_df_congruent_rt_positive['rt'].std(),
                                         negative_first_df_congruent_rt_negative['rt'].std()]

# %%
grouped = positive_first_rt_incongruent_df.groupby('condition')
positive_first_incongruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        positive_first_incongruent_no_trainig = positive_first_incongruent_no_trainig.append(group)



grouped = positive_first_incongruent_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        incongruent_training_set = group
    elif name == 1:
        positive_first_incongruent_rt_baseline = group
    elif name == 2:
        positive_first_incongruent_rt_positive = group
    elif name == 3:
        positive_first_incongruent_rt_negative = group
        
        
positive_first_df_rt_incongruent = pd.DataFrame()
positive_first_df_rt_incongruent['baseline'] = [positive_first_incongruent_rt_baseline['rt'].mean()]
positive_first_df_rt_incongruent['positive'] = positive_first_incongruent_rt_positive['rt'].mean()
positive_first_df_rt_incongruent['negative'] = positive_first_incongruent_rt_negative['rt'].mean()
rt_congruent


positive_first_df_rt_incongruent = positive_first_df_rt_incongruent.T.rename(columns={0: 'mean rt'})

positive_first_df_rt_incongruent['std'] = [positive_first_incongruent_rt_baseline['rt'].std(),
                                           positive_first_incongruent_rt_positive['rt'].std(),
                                           positive_first_incongruent_rt_negative['rt'].std()]


## Incongruent

        
grouped = positive_first_rt_congruent_df.groupby('condition')

positive_first_congruent_no_trainig = pd.DataFrame()

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    else:
        positive_first_congruent_no_trainig = positive_first_congruent_no_trainig.append(group)



grouped = positive_first_congruent_no_trainig.groupby('condition')

# iterate over split dataframes
for name, group in grouped:
    #print(name)
    #display(group)
    if name == 0:
        congruent_training_set = group
    elif name == 1:
        positive_first_df_congruent_rt_baseline = group
    elif name == 2:
        positive_first_df_congruent_rt_positive = group
    elif name == 3:
        positive_first_df_congruent_rt_negative = group
        
positive_first_df_rt_congruent = pd.DataFrame()
positive_first_df_rt_congruent['baseline'] = [positive_first_df_congruent_rt_baseline['rt'].mean()]
positive_first_df_rt_congruent['positive'] = positive_first_df_congruent_rt_positive['rt'].mean()
positive_first_df_rt_congruent['negative'] = positive_first_df_congruent_rt_negative['rt'].mean()
rt_congruent


positive_first_df_rt_congruent = positive_first_df_rt_congruent.T.rename(columns={0: 'mean rt'})

positive_first_df_rt_congruent['std'] = [positive_first_df_congruent_rt_baseline['rt'].std(), positive_first_df_congruent_rt_positive['rt'].std(),
                       positive_first_df_congruent_rt_negative['rt'].std()]

# %%
sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)

ax.plot(positive_first_df_rt_incongruent['mean rt'].to_numpy(), color='r')

# draw custom error bars
plt.plot([0, 0], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] + positive_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] - positive_first_df_rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)

plt.plot([1, 1], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] + positive_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] - positive_first_df_rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)

plt.plot([2, 2], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] + positive_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] - positive_first_df_rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)


plt.plot([-0.02, 0.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] + positive_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] + positive_first_df_rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)

plt.plot([-0.02, 0.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] - positive_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] - positive_first_df_rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)


plt.plot([0.98, 1.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] + positive_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] + positive_first_df_rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)


plt.plot([0.98, 1.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] - positive_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] - positive_first_df_rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)

plt.plot([1.98, 2.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] + positive_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] + positive_first_df_rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)

plt.plot([1.98, 2.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] - positive_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] - positive_first_df_rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)


ax.plot(positive_first_df_rt_congruent['mean rt'].to_numpy(), color='cornflowerblue')

# draw custom error bars
plt.plot([0, 0], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[0] + positive_first_df_rt_congruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[0] - positive_first_df_rt_congruent['std'].to_numpy()[0])],
                  'cornflowerblue', lw=0.5)

plt.plot([1, 1], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[1] + positive_first_df_rt_congruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[1] - positive_first_df_rt_congruent['std'].to_numpy()[1])],
                  'cornflowerblue', lw=0.5)

plt.plot([2, 2], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[2] + positive_first_df_rt_congruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[2] - positive_first_df_rt_congruent['std'].to_numpy()[2])],
                  'cornflowerblue', lw=0.5)


plt.plot([-0.02, 0.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[0] + positive_first_df_rt_congruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[0] + positive_first_df_rt_congruent['std'].to_numpy()[0])],
                  'cornflowerblue', lw=0.5)

plt.plot([-0.02, 0.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[0] - positive_first_df_rt_congruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[0] - positive_first_df_rt_congruent['std'].to_numpy()[0])],
                  'cornflowerblue', lw=0.5)


plt.plot([0.98, 1.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[1] + positive_first_df_rt_congruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[1] + positive_first_df_rt_congruent['std'].to_numpy()[1])],
                  'cornflowerblue', lw=0.5)


plt.plot([0.98, 1.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[1] - positive_first_df_rt_congruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[1] - positive_first_df_rt_congruent['std'].to_numpy()[1])],
                  'cornflowerblue', lw=0.5)

plt.plot([1.98, 2.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[2] + positive_first_df_rt_congruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[2] + positive_first_df_rt_congruent['std'].to_numpy()[2])],
                  'cornflowerblue', lw=0.5)

plt.plot([1.98, 2.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[2] - positive_first_df_rt_congruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[2] - positive_first_df_rt_congruent['std'].to_numpy()[2])],
                  'cornflowerblue', lw=0.5)


#### Negative First

ax.plot(negative_first_df_rt_incongruent['mean rt'].to_numpy(), color='maroon')
#ax.plot(rt_incongruent['mean rt'].to_numpy()- rt_incongruent['std'].to_numpy(), color='r', alpha=0.2)
#ax.plot(rt_incongruent['mean rt'].to_numpy()+ rt_incongruent['std'].to_numpy(), color='r', alpha=0.2)

#ax.fill_between(np.arange(len(rt_incongruent['mean rt'].to_numpy())),
#                 rt_incongruent['mean rt'].to_numpy() - rt_incongruent['std'].to_numpy(),
#                 rt_incongruent['mean rt'].to_numpy() + rt_incongruent['std'].to_numpy(), color='r', alpha=0.07)

# draw custom error bars
plt.plot([0, 0], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] + negative_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] - negative_first_df_rt_incongruent['std'].to_numpy()[0])],
                  'maroon', lw=0.5)

plt.plot([1, 1], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] + negative_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] - negative_first_df_rt_incongruent['std'].to_numpy()[1])], 
                  'maroon', lw=0.5)

plt.plot([2, 2], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] + negative_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] - negative_first_df_rt_incongruent['std'].to_numpy()[2])],
                  'maroon', lw=0.5)


plt.plot([-0.02, 0.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] + negative_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] + negative_first_df_rt_incongruent['std'].to_numpy()[0])],
                   'maroon', lw=0.5)

plt.plot([-0.02, 0.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] - negative_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] - negative_first_df_rt_incongruent['std'].to_numpy()[0])],
                   'maroon', lw=0.5)


plt.plot([0.98, 1.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] + negative_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] + negative_first_df_rt_incongruent['std'].to_numpy()[1])],
                   'maroon', lw=0.5)


plt.plot([0.98, 1.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] - negative_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] - negative_first_df_rt_incongruent['std'].to_numpy()[1])],
                   'maroon', lw=0.5)

plt.plot([1.98, 2.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] + negative_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] + negative_first_df_rt_incongruent['std'].to_numpy()[2])],
                   'maroon', lw=0.5)

plt.plot([1.98, 2.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] - negative_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] - negative_first_df_rt_incongruent['std'].to_numpy()[2])],
                   'maroon', lw=0.5)


ax.plot(negative_first_df_rt_congruent['mean rt'].to_numpy(), color='midnightblue')
#ax.plot(rt_congruent['mean rt'].to_numpy()- rt_congruent['std'].to_numpy(), color='b', alpha=0.2)
#ax.plot(rt_congruent['mean rt'].to_numpy()+ rt_congruent['std'].to_numpy(), color='b', alpha=0.2)

#ax.fill_between(np.arange(len(rt_congruent['mean rt'].to_numpy())),
#                 rt_congruent['mean rt'].to_numpy() - rt_congruent['std'].to_numpy(),
#                 rt_congruent['mean rt'].to_numpy() + rt_congruent['std'].to_numpy(), color='b', alpha=0.07)

# draw custom error bars
plt.plot([0, 0], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[0] + negative_first_df_rt_congruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[0] - negative_first_df_rt_congruent['std'].to_numpy()[0])],
                  'midnightblue', lw=0.5)

plt.plot([1, 1], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[1] + negative_first_df_rt_congruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[1] - negative_first_df_rt_congruent['std'].to_numpy()[1])],
                  'midnightblue', lw=0.5)

plt.plot([2, 2], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[2] + negative_first_df_rt_congruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[2] - negative_first_df_rt_congruent['std'].to_numpy()[2])],
                  'midnightblue', lw=0.5)


plt.plot([-0.02, 0.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[0] + negative_first_df_rt_congruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[0] + negative_first_df_rt_congruent['std'].to_numpy()[0])],
                   'midnightblue', lw=0.5)

plt.plot([-0.02, 0.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[0] - negative_first_df_rt_congruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[0] - negative_first_df_rt_congruent['std'].to_numpy()[0])],
                   'midnightblue', lw=0.5)


plt.plot([0.98, 1.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[1] + negative_first_df_rt_congruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[1] + negative_first_df_rt_congruent['std'].to_numpy()[1])],
                   'midnightblue', lw=0.5)


plt.plot([0.98, 1.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[1] - negative_first_df_rt_congruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[1] - negative_first_df_rt_congruent['std'].to_numpy()[1])],
                   'midnightblue', lw=0.5)

plt.plot([1.98, 2.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[2] + negative_first_df_rt_congruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[2] + negative_first_df_rt_congruent['std'].to_numpy()[2])],
                   'midnightblue', lw=0.5)

plt.plot([1.98, 2.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[2] - negative_first_df_rt_congruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[2] - negative_first_df_rt_congruent['std'].to_numpy()[2])],
                   'midnightblue', lw=0.5)


fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.2, 0.5)


pos_incongruent_leg = mpatches.Patch(color='r', label='incongruent positive first')
pos_congruent_leg = mpatches.Patch(color='cornflowerblue', label='congruent positive first')

neg_incongruent_leg = mpatches.Patch(color='maroon', label='incongruent negative first')
neg_congruent_leg = mpatches.Patch(color='midnightblue', label='congruent negative first')

plt.legend(handles=[neg_congruent_leg, pos_congruent_leg, neg_incongruent_leg, pos_incongruent_leg])

plt.show()

# %%
sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


#### Negative First

ax.plot(negative_first_df_rt_incongruent['mean rt'].to_numpy(), color='maroon')

# draw custom error bars
plt.plot([0, 0], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] + negative_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] - negative_first_df_rt_incongruent['std'].to_numpy()[0])],
                  'maroon', lw=0.5)

plt.plot([1, 1], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] + negative_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] - negative_first_df_rt_incongruent['std'].to_numpy()[1])], 
                  'maroon', lw=0.5)

plt.plot([2, 2], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] + negative_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] - negative_first_df_rt_incongruent['std'].to_numpy()[2])],
                  'maroon', lw=0.5)


plt.plot([-0.02, 0.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] + negative_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] + negative_first_df_rt_incongruent['std'].to_numpy()[0])],
                   'maroon', lw=0.5)

plt.plot([-0.02, 0.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] - negative_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[0] - negative_first_df_rt_incongruent['std'].to_numpy()[0])],
                   'maroon', lw=0.5)


plt.plot([0.98, 1.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] + negative_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] + negative_first_df_rt_incongruent['std'].to_numpy()[1])],
                   'maroon', lw=0.5)


plt.plot([0.98, 1.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] - negative_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[1] - negative_first_df_rt_incongruent['std'].to_numpy()[1])],
                   'maroon', lw=0.5)

plt.plot([1.98, 2.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] + negative_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] + negative_first_df_rt_incongruent['std'].to_numpy()[2])],
                   'maroon', lw=0.5)

plt.plot([1.98, 2.02], [(negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] - negative_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_incongruent['mean rt'].to_numpy()[2] - negative_first_df_rt_incongruent['std'].to_numpy()[2])],
                   'maroon', lw=0.5)


ax.plot(negative_first_df_rt_congruent['mean rt'].to_numpy(), color='midnightblue')
#ax.plot(rt_congruent['mean rt'].to_numpy()- rt_congruent['std'].to_numpy(), color='b', alpha=0.2)
#ax.plot(rt_congruent['mean rt'].to_numpy()+ rt_congruent['std'].to_numpy(), color='b', alpha=0.2)

#ax.fill_between(np.arange(len(rt_congruent['mean rt'].to_numpy())),
#                 rt_congruent['mean rt'].to_numpy() - rt_congruent['std'].to_numpy(),
#                 rt_congruent['mean rt'].to_numpy() + rt_congruent['std'].to_numpy(), color='b', alpha=0.07)

# draw custom error bars
plt.plot([0, 0], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[0] + negative_first_df_rt_congruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[0] - negative_first_df_rt_congruent['std'].to_numpy()[0])],
                  'midnightblue', lw=0.5)

plt.plot([1, 1], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[1] + negative_first_df_rt_congruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[1] - negative_first_df_rt_congruent['std'].to_numpy()[1])],
                  'midnightblue', lw=0.5)

plt.plot([2, 2], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[2] + negative_first_df_rt_congruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[2] - negative_first_df_rt_congruent['std'].to_numpy()[2])],
                  'midnightblue', lw=0.5)


plt.plot([-0.02, 0.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[0] + negative_first_df_rt_congruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[0] + negative_first_df_rt_congruent['std'].to_numpy()[0])],
                   'midnightblue', lw=0.5)

plt.plot([-0.02, 0.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[0] - negative_first_df_rt_congruent['std'].to_numpy()[0]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[0] - negative_first_df_rt_congruent['std'].to_numpy()[0])],
                   'midnightblue', lw=0.5)


plt.plot([0.98, 1.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[1] + negative_first_df_rt_congruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[1] + negative_first_df_rt_congruent['std'].to_numpy()[1])],
                   'midnightblue', lw=0.5)


plt.plot([0.98, 1.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[1] - negative_first_df_rt_congruent['std'].to_numpy()[1]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[1] - negative_first_df_rt_congruent['std'].to_numpy()[1])],
                   'midnightblue', lw=0.5)

plt.plot([1.98, 2.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[2] + negative_first_df_rt_congruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[2] + negative_first_df_rt_congruent['std'].to_numpy()[2])],
                   'midnightblue', lw=0.5)

plt.plot([1.98, 2.02], [(negative_first_df_rt_congruent['mean rt'].to_numpy()[2] - negative_first_df_rt_congruent['std'].to_numpy()[2]),
                  (negative_first_df_rt_congruent['mean rt'].to_numpy()[2] - negative_first_df_rt_congruent['std'].to_numpy()[2])],
                   'midnightblue', lw=0.5)


fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[2] = 'Negative'
labels[3] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.2, 0.5)

neg_incongruent_leg = mpatches.Patch(color='maroon', label='incongruent negative first')
neg_congruent_leg = mpatches.Patch(color='midnightblue', label='congruent negative first')

plt.legend(handles=[neg_congruent_leg, neg_incongruent_leg])

plt.show()

# %%
negative_first_df_rt_congruent
# Out:
#            mean rt       std
# baseline  0.388949  0.091054
# positive  0.380486  0.085912
# negative  0.383739  0.090518

# %%
sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(12,8))
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)

ax.plot(positive_first_df_rt_incongruent['mean rt'].to_numpy(), color='r')

# draw custom error bars
plt.plot([0, 0], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] + positive_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] - positive_first_df_rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)

plt.plot([1, 1], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] + positive_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] - positive_first_df_rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)

plt.plot([2, 2], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] + positive_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] - positive_first_df_rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)


plt.plot([-0.02, 0.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] + positive_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] + positive_first_df_rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)

plt.plot([-0.02, 0.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] - positive_first_df_rt_incongruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[0] - positive_first_df_rt_incongruent['std'].to_numpy()[0])], 'r', lw=0.5)


plt.plot([0.98, 1.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] + positive_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] + positive_first_df_rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)

plt.plot([0.98, 1.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] - positive_first_df_rt_incongruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[2] - positive_first_df_rt_incongruent['std'].to_numpy()[1])], 'r', lw=0.5)


plt.plot([1.98, 2.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] + positive_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] + positive_first_df_rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)

plt.plot([1.98, 2.02], [(positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] - positive_first_df_rt_incongruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_incongruent['mean rt'].to_numpy()[1] - positive_first_df_rt_incongruent['std'].to_numpy()[2])], 'r', lw=0.5)


ax.plot(positive_first_df_rt_congruent['mean rt'].to_numpy(), color='cornflowerblue')

# draw custom error bars
plt.plot([0, 0], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[0] + positive_first_df_rt_congruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[0] - positive_first_df_rt_congruent['std'].to_numpy()[0])],
                  'cornflowerblue', lw=0.5)

plt.plot([1, 1], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[2] + positive_first_df_rt_congruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[2] - positive_first_df_rt_congruent['std'].to_numpy()[1])],
                  'cornflowerblue', lw=0.5)

plt.plot([2, 2], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[1] + positive_first_df_rt_congruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[1] - positive_first_df_rt_congruent['std'].to_numpy()[2])],
                  'cornflowerblue', lw=0.5)


plt.plot([-0.02, 0.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[0] + positive_first_df_rt_congruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[0] + positive_first_df_rt_congruent['std'].to_numpy()[0])],
                  'cornflowerblue', lw=0.5)

plt.plot([-0.02, 0.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[0] - positive_first_df_rt_congruent['std'].to_numpy()[0]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[0] - positive_first_df_rt_congruent['std'].to_numpy()[0])],
                  'cornflowerblue', lw=0.5)


plt.plot([0.98, 1.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[2] + positive_first_df_rt_congruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[2] + positive_first_df_rt_congruent['std'].to_numpy()[1])],
                  'cornflowerblue', lw=0.5)


plt.plot([0.98, 1.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[2] - positive_first_df_rt_congruent['std'].to_numpy()[1]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[2] - positive_first_df_rt_congruent['std'].to_numpy()[1])],
                  'cornflowerblue', lw=0.5)

plt.plot([1.98, 2.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[1] + positive_first_df_rt_congruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[1] + positive_first_df_rt_congruent['std'].to_numpy()[2])],
                  'cornflowerblue', lw=0.5)

plt.plot([1.98, 2.02], [(positive_first_df_rt_congruent['mean rt'].to_numpy()[1] - positive_first_df_rt_congruent['std'].to_numpy()[2]),
                  (positive_first_df_rt_congruent['mean rt'].to_numpy()[1] - positive_first_df_rt_congruent['std'].to_numpy()[2])],
                  'cornflowerblue', lw=0.5)


fig.canvas.draw()

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Baseline'
labels[3] = 'Negative'
labels[2] = 'Positive'

ax.set_xticklabels(labels)

plt.ylim(0.2, 0.5)


pos_incongruent_leg = mpatches.Patch(color='r', label='incongruent positive first')
pos_congruent_leg = mpatches.Patch(color='cornflowerblue', label='congruent positive first')


plt.legend(handles=[pos_congruent_leg, pos_incongruent_leg])

plt.show()

# %%
positive_first_df_rt_congruent = positive_first_df_rt_congruent.T
positive_first_df_rt_incongruent = positive_first_df_rt_incongruent.T

negative_first_df_rt_congruent = negative_first_df_rt_congruent.T
negative_first_df_rt_incongruent = negative_first_df_rt_incongruent.T

# %%
positive_first_df_rt_congruent
# Out:
#          baseline  positive  negative
# mean rt  0.375317  0.353973  0.356269
# std      0.094366  0.074401  0.076364

# %%
positive_first_df_rt_congruent = positive_first_df_rt_congruent.rename(columns={'baseline':'baseline_positive_congruent',
                                               'positive':'1.Block_positive_positive_congruent',
                                               'negative':'2.Block_negative_positive_congruent'})

positive_first_df_rt_incongruent = positive_first_df_rt_incongruent.rename(columns={'baseline':'baseline_positive_incongruent',
                                               'positive':'1.Block_positive_positive_incongruent',
                                               'negative':'2.Block_negative_positive_incongruent'})

negative_first_df_rt_congruent = positive_first_df_rt_congruent.rename(columns={'baseline':'baseline_positive_congruent',
                                               'positive':'1.Block_positive_positive_congruent',
                                               'negative':'2.Block_negative_positive_congruent'})

negative_first_df_rt_incongruent = positive_first_df_rt_incongruent.rename(columns={'baseline':'baseline_positive_incongruent',
                                               'positive':'1.Block_negative_negative_incongruent',
                                               'negative':'2.Block_negative_positive_incongruent'})

# %%
rt_means = pd.concat([positive_first_df_rt_congruent.T, positive_first_df_rt_incongruent.T,
                      negative_first_df_rt_congruent.T, negative_first_df_rt_incongruent.T])

# %%
rt_means
# Out:
#                                         mean rt       std
# baseline_positive_congruent            0.375317  0.094366
# 1.Block_positive_positive_congruent    0.353973  0.074401
# 2.Block_negative_positive_congruent    0.356269  0.076364
# baseline_positive_incongruent          0.320401  0.089983
# 1.Block_positive_positive_incongruent  0.310283  0.083599
# 2.Block_negative_positive_incongruent  0.314328  0.083456
# baseline_positive_congruent            0.375317  0.094366
# 1.Block_positive_positive_congruent    0.353973  0.074401
# 2.Block_negative_positive_congruent    0.356269  0.076364
# baseline_positive_incongruent          0.320401  0.089983
# 1.Block_positive_positive_incongruent  0.310283  0.083599
# 2.Block_negative_positive_incongruent  0.314328  0.083456

# %%
positive_first_df_rt_congruent.columns
# Out:
# Index(['mean rt', 'std'], dtype='object')

# %%
rt_means.to_csv('/home/michael/git/master_thesis/data/reaction_times_means_+_std.tsv', sep='\t', index=False)
